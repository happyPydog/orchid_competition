# %% [markdown]
# # 環境

# %% [markdown]
# 我們在這次競賽所需的套件都可以直接在 colab 上import，除了 timm。
#
# timm 是一個 pre-trained 好的圖形分類模型，很適合用在本次競賽較小的資料集。
#
# 以下我們先下載最新版本的 timm。
#
# 這裡要直接從 github 下載，因為我們使用的模型需要比較新的版本才有，
#
# 因此如果直接用 pip sintall timm 就沒辦法使用之後會用到的模型。

# %%
# import需要用到的套件
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torchvision
from torchvision import transforms
from tqdm.notebook import tqdm

# %%
# !pip install git+https://github.com/rwightman/pytorch-image-models.git
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting git+https://github.com/rwightman/pytorch-image-models.git
#   Cloning https://github.com/rwightman/pytorch-image-models.git to /tmp/pip-req-build-_rywint4
#   Running command git clone -q https://github.com/rwightman/pytorch-image-models.git /tmp/pip-req-build-_rywint4
# Requirement already satisfied: torch>=1.4 in /usr/local/lib/python3.7/dist-packages (from timm==0.6.2.dev0) (1.11.0+cu113)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from timm==0.6.2.dev0) (0.12.0+cu113)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.4->timm==0.6.2.dev0) (4.2.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torchvision->timm==0.6.2.dev0) (1.21.6)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision->timm==0.6.2.dev0) (7.1.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from torchvision->timm==0.6.2.dev0) (2.23.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision->timm==0.6.2.dev0) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision->timm==0.6.2.dev0) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision->timm==0.6.2.dev0) (2022.5.18.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision->timm==0.6.2.dev0) (2.10)
# Building wheels for collected packages: timm
#   Building wheel for timm (setup.py) ... done
#   Created wheel for timm: filename=timm-0.6.2.dev0-py3-none-any.whl size=498066 sha256=640089da97c20501c2319397c799b8c7ec6093805d34302fc6f8a8ff6ee601b8
#   Stored in directory: /tmp/pip-ephem-wheel-cache-prtops1i/wheels/a0/ec/5f/289118b747739bb1e02e36cf3d7e759721e881c183653719dc
# Successfully built timm
# Installing collected packages: timm
# Successfully installed timm-0.6.2.dev0

# %% [markdown]
# # 準備資料

# %%
# 從雲端下載 training.zip
import gdown

url = "https://drive.google.com/u/4/uc?id=1KT_mJEdYtOXF79gdwgQsjmZQfzQS3ApU&export=download"
output = "training.zip"
gdown.download(url, output)
# Out:
# Downloading...
# From: https://drive.google.com/u/4/uc?id=1KT_mJEdYtOXF79gdwgQsjmZQfzQS3ApU&export=download
# To: /content/training.zip
# 100%|██████████| 90.7M/90.7M [00:02<00:00, 39.6MB/s]
# 'training.zip'

# %%
# 解壓縮 training.zip 到 data 資料夾
# !unzip "training.zip" -d "data"
# Out:
# Archive:  training.zip
#   inflating: data/02a91mzn84.jpg
#   inflating: data/02nehv1tf6.jpg
#   inflating: data/02sx9ijfd6.jpg
#   inflating: data/032p7z15ol.jpg
#   inflating: data/03jezhu9i8.jpg
#   inflating: data/03ol9zqjn7.jpg
#   inflating: data/04d6xbohpg.jpg
#   inflating: data/04kxsd2rf9.jpg
#   inflating: data/05tdemvcqx.jpg
#   inflating: data/06uasyi3nt.jpg
#   inflating: data/07ufd3njrv.jpg
#   inflating: data/07uqc9hdnt.jpg
#   inflating: data/084dzytmfe.jpg
#   inflating: data/09de32ybos.jpg
#   inflating: data/0a1h7votc5.jpg
#   inflating: data/0a7yscrh49.jpg
#   inflating: data/0clzd3aqyg.jpg
#   inflating: data/0cwbio2hfn.jpg
#   inflating: data/0d9ucgfmy6.jpg
#   inflating: data/0dhgmwk8ri.jpg
#   inflating: data/0dwec2hx45.jpg
#   inflating: data/0e1u74idof.jpg
#   inflating: data/0eac5fkrg6.jpg
#   inflating: data/0evyz4ogbj.jpg
#   inflating: data/0f2wec1id9.jpg
#   inflating: data/0gawub3e76.jpg
#   inflating: data/0gnjdfq4tu.jpg
#   inflating: data/0h5c84vtlw.jpg
#   inflating: data/0j2v53fyn1.jpg
#   inflating: data/0ja1dvs6gf.jpg
#   inflating: data/0jfd1cxlmv.jpg
#   inflating: data/0kdx4m6jav.jpg
#   inflating: data/0kv8j7wohr.jpg
#   inflating: data/0li9wram6f.jpg
#   inflating: data/0ndfk7y2jv.jpg
#   inflating: data/0rv9woke27.jpg
#   inflating: data/0s8dp7i69a.jpg
#   inflating: data/0tcrqbus31.jpg
#   inflating: data/0txhk2rbud.jpg
#   inflating: data/0tzkesu7vh.jpg
#   inflating: data/0uijyo2btd.jpg
#   inflating: data/0v6mgkl3o2.jpg
#   inflating: data/0vkloujhna.jpg
#   inflating: data/0vo6mh4bi5.jpg
#   inflating: data/0vq9ct7mg1.jpg
#   inflating: data/0whe2yom8g.jpg
#   inflating: data/0x9k2t6f5w.jpg
#   inflating: data/0xgifkj7pc.jpg
#   inflating: data/0xyi4gpvjl.jpg
#   inflating: data/0y3epg8s2a.jpg
#   inflating: data/0yfkw35h1m.jpg
#   inflating: data/0zjbvpworf.jpg
#   inflating: data/0znihwd17c.jpg
#   inflating: data/10mkbruhvi.jpg
#   inflating: data/12ayikhepq.jpg
#   inflating: data/12ish7g0zt.jpg
#   inflating: data/12skpjbwn6.jpg
#   inflating: data/12yhed8ic0.jpg
#   inflating: data/14j7cbrunh.jpg
#   inflating: data/15tsi03djc.jpg
#   inflating: data/16hyv9mz8g.jpg
#   inflating: data/16lyj3csrk.jpg
#   inflating: data/16p7w48agz.jpg
#   inflating: data/17at8fyrjz.jpg
#   inflating: data/17bz5tgpf8.jpg
#   inflating: data/18roqtwzmx.jpg
#   inflating: data/19au3ysioc.jpg
#   inflating: data/19urj54ob7.jpg
#   inflating: data/1alfpuo7wx.jpg
#   inflating: data/1bysp7e9xv.jpg
#   inflating: data/1c3ou9kyvl.jpg
#   inflating: data/1czdhke8jq.jpg
#   inflating: data/1dx8hjnbgf.jpg
#   inflating: data/1dyz2gk7br.jpg
#   inflating: data/1ecpbl689n.jpg
#   inflating: data/1enqlvtxo6.jpg
#   inflating: data/1gjn5y6bur.jpg
#   inflating: data/1h5kftvwp8.jpg
#   inflating: data/1h8rx6lv9u.jpg
#   inflating: data/1hm8ijb0vk.jpg
#   inflating: data/1ic9ys5fem.jpg
#   inflating: data/1jf89myh73.jpg
#   inflating: data/1jwyervk87.jpg
#   inflating: data/1k2foyiqlv.jpg
#   inflating: data/1kmopz5fuc.jpg
#   inflating: data/1kt9palgbf.jpg
#   inflating: data/1ky6uhg4n2.jpg
#   inflating: data/1l4enr6axm.jpg
#   inflating: data/1lebnyzs98.jpg
#   inflating: data/1lezfh2jgv.jpg
#   inflating: data/1moguienbk.jpg
#   inflating: data/1netcyzdol.jpg
#   inflating: data/1obsiaeh65.jpg
#   inflating: data/1ofy7jk3li.jpg
#   inflating: data/1ozqv5bhxe.jpg
#   inflating: data/1pqnt0w2gm.jpg
#   inflating: data/1q8dk4lsc2.jpg
#   inflating: data/1r2305vbfi.jpg
#   inflating: data/1rcw0xhaz6.jpg
#   inflating: data/1suz7kac89.jpg
#   inflating: data/1v2gcmxqw0.jpg
#   inflating: data/1vqyj3280z.jpg
#   inflating: data/1vsnjdzkxc.jpg
#   inflating: data/1wgtc42meh.jpg
#   inflating: data/1xlq475kg9.jpg
#   inflating: data/1y8v9uoerm.jpg
#   inflating: data/1z4h7la69v.jpg
#   inflating: data/216ulqy9je.jpg
#   inflating: data/23680fkbw1.jpg
#   inflating: data/2391qpv8cs.jpg
#   inflating: data/23gwe6jfd5.jpg
#   inflating: data/240psvcag7.jpg
#   inflating: data/24exlyszi1.jpg
#   inflating: data/264zmpgj5h.jpg
#   inflating: data/26pul9rjdn.jpg
#   inflating: data/27zahs4k9l.jpg
#   inflating: data/283irngatu.jpg
#   inflating: data/29nogjzqm4.jpg
#   inflating: data/29qxzcmn65.jpg
#   inflating: data/2a7qg8pwch.jpg
#   inflating: data/2b45qrx6cd.jpg
#   inflating: data/2bu4kndtxv.jpg
#   inflating: data/2bxai7um13.jpg
#   inflating: data/2cepd1oy7t.jpg
#   inflating: data/2cihfpdmx3.jpg
#   inflating: data/2cjmveo601.jpg
#   inflating: data/2cna7gw95u.jpg
#   inflating: data/2d8tl7v1hp.jpg
#   inflating: data/2dhpo9n1g4.jpg
#   inflating: data/2dqv43cn1u.jpg
#   inflating: data/2e9cqb73xg.jpg
#   inflating: data/2ecmfbq3x9.jpg
#   inflating: data/2eths8c9vn.jpg
#   inflating: data/2ex1dclf3w.jpg
#   inflating: data/2g5snbv8r6.jpg
#   inflating: data/2gjuevhqxa.jpg
#   inflating: data/2glsqz7bpf.jpg
#   inflating: data/2hy0a68iq4.jpg
#   inflating: data/2hydouif75.jpg
#   inflating: data/2ir0kwam6n.jpg
#   inflating: data/2j8bxnh640.jpg
#   inflating: data/2jix9katr4.jpg
#   inflating: data/2jk58mvldh.jpg
#   inflating: data/2jog39e7u1.jpg
#   inflating: data/2ke6vdnu95.jpg
#   inflating: data/2kijb9dafn.jpg
#   inflating: data/2kuvwm3y6a.jpg
#   inflating: data/2l3yac8t0h.jpg
#   inflating: data/2le43zcqfj.jpg
#   inflating: data/2ln8p7k6o5.jpg
#   inflating: data/2lrxn17mv0.jpg
#   inflating: data/2lsfjw0cog.jpg
#   inflating: data/2lvns5x9zk.jpg
#   inflating: data/2m87ikb03x.jpg
#   inflating: data/2mrz7of1j9.jpg
#   inflating: data/2n3hi80pw5.jpg
#   inflating: data/2nfdbv5gz3.jpg
#   inflating: data/2nye78pot5.jpg
#   inflating: data/2od971bwn0.jpg
#   inflating: data/2pdsgyxir6.jpg
#   inflating: data/2pns8ayv31.jpg
#   inflating: data/2qacykxz5s.jpg
#   inflating: data/2qhfvy49ar.jpg
#   inflating: data/2qyjkac5xr.jpg
#   inflating: data/2r4pswl6q5.jpg
#   inflating: data/2s03zy8k5x.jpg
#   inflating: data/2srnlmzx47.jpg
#   inflating: data/2sw6jh5c9g.jpg
#   inflating: data/2tnuikdfbp.jpg
#   inflating: data/2uhcpewqmk.jpg
#   inflating: data/2ulegn7fxp.jpg
#   inflating: data/2v0bp31iku.jpg
#   inflating: data/2vza9frwle.jpg
#   inflating: data/2vzg9j1kbr.jpg
#   inflating: data/2w89rtl7jd.jpg
#   inflating: data/2xu3jb9w4c.jpg
#   inflating: data/2yhkn0qgt8.jpg
#   inflating: data/2zsfdbrex4.jpg
#   inflating: data/3065yl8zwn.jpg
#   inflating: data/30ajyigdcu.jpg
#   inflating: data/310fyoh8jx.jpg
#   inflating: data/316kp84gzx.jpg
#   inflating: data/31yivcarl7.jpg
#   inflating: data/324o5bp1dy.jpg
#   inflating: data/32bjm0oyxh.jpg
#   inflating: data/32fzagoneb.jpg
#   inflating: data/347q2106gk.jpg
#   inflating: data/35riksogl0.jpg
#   inflating: data/3762cgkobs.jpg
#   inflating: data/37ljg2i5vw.jpg
#   inflating: data/395ogwhz1d.jpg
#   inflating: data/39y6ns5mcb.jpg
#   inflating: data/3aegm7bpyk.jpg
#   inflating: data/3bje5my9kh.jpg
#   inflating: data/3bowep7uy5.jpg
#   inflating: data/3c2hnxmybs.jpg
#   inflating: data/3c76hjmz0s.jpg
#   inflating: data/3displcbjm.jpg
#   inflating: data/3dkx0y9ben.jpg
#   inflating: data/3dzgvj45fl.jpg
#   inflating: data/3f47vrk21p.jpg
#   inflating: data/3fihwbdlt2.jpg
#   inflating: data/3fwiax1g6v.jpg
#   inflating: data/3hd6c94285.jpg
#   inflating: data/3i0nf1mx24.jpg
#   inflating: data/3ic42ol7ub.jpg
#   inflating: data/3imr5hlfp6.jpg
#   inflating: data/3j7foxnqlu.jpg
#   inflating: data/3jdlrqgcz4.jpg
#   inflating: data/3jlcz4rnwp.jpg
#   inflating: data/3jpy6cmnbr.jpg
#   inflating: data/3jsy6vdb5n.jpg
#   inflating: data/3k5sm6icg4.jpg
#   inflating: data/3kc085ur1p.jpg
#   inflating: data/3kpfvoexgm.jpg
#   inflating: data/3kt9eydpls.jpg
#   inflating: data/3l1h5kfut9.jpg
#   inflating: data/3lw8i1mpa2.jpg
#   inflating: data/3mankqhup7.jpg
#   inflating: data/3mvt6ayelz.jpg
#   inflating: data/3oif52dw14.jpg
#   inflating: data/3pe0du57w2.jpg
#   inflating: data/3qih2j9l46.jpg
#   inflating: data/3r8vhx2jmy.jpg
#   inflating: data/3ra4b0zjon.jpg
#   inflating: data/3rshz5gvja.jpg
#   inflating: data/3swmn4zuv0.jpg
#   inflating: data/3tianfl4rk.jpg
#   inflating: data/3v4ja9rkuo.jpg
#   inflating: data/3vowbsjg06.jpg
#   inflating: data/3vr6axohik.jpg
#   inflating: data/3w02s5jpnz.jpg
#   inflating: data/3xbyz5d6p0.jpg
#   inflating: data/3xk1wopr6s.jpg
#   inflating: data/3yqn097hfv.jpg
#   inflating: data/3z4lrcpo6n.jpg
#   inflating: data/403kzd58gw.jpg
#   inflating: data/40j5ksl7om.jpg
#   inflating: data/40pzc6lty3.jpg
#   inflating: data/410je2qt56.jpg
#   inflating: data/41i3lxpjwu.jpg
#   inflating: data/43a86kwq5n.jpg
#   inflating: data/43jkmp0i1y.jpg
#   inflating: data/43q6y7vh2j.jpg
#   inflating: data/43reufjtbk.jpg
#   inflating: data/43tozprjky.jpg
#   inflating: data/43zli5mu1h.jpg
#   inflating: data/46xw80hkz1.jpg
#   inflating: data/472c1db59e.jpg
#   inflating: data/49knz0j8e1.jpg
#   inflating: data/49mgbl6kjf.jpg
#   inflating: data/49n1retqbw.jpg
#   inflating: data/4anwm0t7y6.jpg
#   inflating: data/4b62xnfwu3.jpg
#   inflating: data/4b8opr57nl.jpg
#   inflating: data/4bn7zo5sh8.jpg
#   inflating: data/4bpk81twni.jpg
#   inflating: data/4c2dgzevt5.jpg
#   inflating: data/4d0xa5yg38.jpg
#   inflating: data/4d576busev.jpg
#   inflating: data/4ef530djqw.jpg
#   inflating: data/4ejuz2nlfg.jpg
#   inflating: data/4gdkj7sivu.jpg
#   inflating: data/4gju5wsr3a.jpg
#   inflating: data/4hef09wsd1.jpg
#   inflating: data/4hmutl07s3.jpg
#   inflating: data/4hwk6nx9sb.jpg
#   inflating: data/4i9kj51xro.jpg
#   inflating: data/4ib09xpyc6.jpg
#   inflating: data/4ithkjluy7.jpg
#   inflating: data/4ix1zfn92m.jpg
#   inflating: data/4j0agpncie.jpg
#   inflating: data/4j3t69lek2.jpg
#   inflating: data/4j90wex27m.jpg
#   inflating: data/4kehfjtrsq.jpg
#   inflating: data/4keqwaotvy.jpg
#   inflating: data/4lmuj1hkqx.jpg
#   inflating: data/4m2oytns0q.jpg
#   inflating: data/4mnb3ijfgx.jpg
#   inflating: data/4nwgzrseim.jpg
#   inflating: data/4oxyaepql1.jpg
#   inflating: data/4plyjux7en.jpg
#   inflating: data/4pxuzcvnje.jpg
#   inflating: data/4py986qfen.jpg
#   inflating: data/4q8xdtenur.jpg
#   inflating: data/4qhrtfv1zo.jpg
#   inflating: data/4rug69hxo1.jpg
#   inflating: data/4rv2foh0yk.jpg
#   inflating: data/4rvchfoz28.jpg
#   inflating: data/4sedlxbw7f.jpg
#   inflating: data/4sxf95pqkl.jpg
#   inflating: data/4ucan0q26o.jpg
#   inflating: data/4udy6c9jiq.jpg
#   inflating: data/4uj97trdgs.jpg
#   inflating: data/4uqmd8yjo7.jpg
#   inflating: data/4uwtasjc53.jpg
#   inflating: data/4uxdhvbat2.jpg
#   inflating: data/4v3cegh9ly.jpg
#   inflating: data/4vd5cjpnm2.jpg
#   inflating: data/4vh5ey82nj.jpg
#   inflating: data/4wsvfi82nh.jpg
#   inflating: data/4x2mwfs13l.jpg
#   inflating: data/4xpa0elowt.jpg
#   inflating: data/4y0kp3td78.jpg
#   inflating: data/4yw0hedpko.jpg
#   inflating: data/50cfrwdg7o.jpg
#   inflating: data/510lwubih8.jpg
#   inflating: data/513i7beatq.jpg
#   inflating: data/51ylk2mdfz.jpg
#   inflating: data/526tfqw04s.jpg
#   inflating: data/52b4z9ls37.jpg
#   inflating: data/52vcn3os4r.jpg
#   inflating: data/52wz6ckjah.jpg
#   inflating: data/530kf2v8c4.jpg
#   inflating: data/5342f170wa.jpg
#   inflating: data/53vntake08.jpg
#   inflating: data/54tsmdypza.jpg
#   inflating: data/56xnqeco0d.jpg
#   inflating: data/572dgxlnbo.jpg
#   inflating: data/57jypxbrq1.jpg
#   inflating: data/57ws9uc8oz.jpg
#   inflating: data/581yzt3xas.jpg
#   inflating: data/583xman1vi.jpg
#   inflating: data/58deo1cvki.jpg
#   inflating: data/58lrkijwg2.jpg
#   inflating: data/58nv7hgwkp.jpg
#   inflating: data/58x4ewncgu.jpg
#   inflating: data/59gdl1w3kf.jpg
#   inflating: data/59z1m4ieht.jpg
#   inflating: data/5a6ltko4hd.jpg
#   inflating: data/5a7l69buyk.jpg
#   inflating: data/5bfoe3qsrn.jpg
#   inflating: data/5c0vsrdtpq.jpg
#   inflating: data/5cdyhl23ps.jpg
#   inflating: data/5ct0bsjr67.jpg
#   inflating: data/5dcobplzfh.jpg
#   inflating: data/5dmrv1yecq.jpg
#   inflating: data/5epn0r2dtx.jpg
#   inflating: data/5fh7zcp8ny.jpg
#   inflating: data/5foaivg7cs.jpg
#   inflating: data/5g1u632jvx.jpg
#   inflating: data/5gonudyvb1.jpg
#   inflating: data/5h27wke0v6.jpg
#   inflating: data/5hezj6917n.jpg
#   inflating: data/5hvlgw7u8i.jpg
#   inflating: data/5hykev6s9f.jpg
#   inflating: data/5i7ktsa84n.jpg
#   inflating: data/5isz8tmbnc.jpg
#   inflating: data/5jr6x2y9p8.jpg
#   inflating: data/5kabs4q6m2.jpg
#   inflating: data/5lo8r9jyeh.jpg
#   inflating: data/5msy97xr4h.jpg
#   inflating: data/5n7309cy4q.jpg
#   inflating: data/5n89rgs7oe.jpg
#   inflating: data/5p9dyk4se7.jpg
#   inflating: data/5pdmtfbclk.jpg
#   inflating: data/5pnr8xzcla.jpg
#   inflating: data/5qewzk21a7.jpg
#   inflating: data/5qf8da31bp.jpg
#   inflating: data/5qh0iegw38.jpg
#   inflating: data/5qo6s08m94.jpg
#   inflating: data/5r1qsxch3g.jpg
#   inflating: data/5ras3dqig7.jpg
#   inflating: data/5sazegv4pl.jpg
#   inflating: data/5t0c9zgjni.jpg
#   inflating: data/5tebim3lx2.jpg
#   inflating: data/5thdogiaum.jpg
#   inflating: data/5thplixr6q.jpg
#   inflating: data/5u47pqwagh.jpg
#   inflating: data/5uj9yevrk6.jpg
#   inflating: data/5ur372glko.jpg
#   inflating: data/5vhjqkxym1.jpg
#   inflating: data/5vhtxdopna.jpg
#   inflating: data/5vjfmc0esr.jpg
#   inflating: data/5vnxlcpw8j.jpg
#   inflating: data/5w1mlp3s8u.jpg
#   inflating: data/5yp3tnqvcd.jpg
#   inflating: data/5zalsobc97.jpg
#   inflating: data/60c5rme1ts.jpg
#   inflating: data/60sqle9mu2.jpg
#   inflating: data/627prawyjz.jpg
#   inflating: data/62jfwk8lzv.jpg
#   inflating: data/63xtqlbvyz.jpg
#   inflating: data/64ayjiou9l.jpg
#   inflating: data/64oj0qtw91.jpg
#   inflating: data/65zgysrm13.jpg
#   inflating: data/67fmhwzi3n.jpg
#   inflating: data/68xm0fo9kp.jpg
#   inflating: data/691rdlbpn0.jpg
#   inflating: data/692b4mx71j.jpg
#   inflating: data/698x4lkaec.jpg
#   inflating: data/69ktyrim7u.jpg
#   inflating: data/6acfjyq9d1.jpg
#   inflating: data/6aheo298kp.jpg
#   inflating: data/6b8kanr4cw.jpg
#   inflating: data/6biot3hemn.jpg
#   inflating: data/6c2xkabuny.jpg
#   inflating: data/6cflj4txud.jpg
#   inflating: data/6ckta9lzo7.jpg
#   inflating: data/6cme1zkb0p.jpg
#   inflating: data/6co70z981h.jpg
#   inflating: data/6dt372ph9b.jpg
#   inflating: data/6e1cyhrjaz.jpg
#   inflating: data/6e1tkdvysn.jpg
#   inflating: data/6e2v7xt45u.jpg
#   inflating: data/6f7kg94lr3.jpg
#   inflating: data/6fgo3dbp7y.jpg
#   inflating: data/6g58i3xt2s.jpg
#   inflating: data/6g5sm1idlk.jpg
#   inflating: data/6glfjz3mpv.jpg
#   inflating: data/6gvxae72p3.jpg
#   inflating: data/6hqy7ud4jc.jpg
#   inflating: data/6htcvonw5d.jpg
#   inflating: data/6il7z1utsm.jpg
#   inflating: data/6j5uxb0as8.jpg
#   inflating: data/6jf8nev9ld.jpg
#   inflating: data/6jmp43euya.jpg
#   inflating: data/6lcuzxyb7j.jpg
#   inflating: data/6o4szjnh19.jpg
#   inflating: data/6psb2z0eox.jpg
#   inflating: data/6puoj8vbcl.jpg
#   inflating: data/6qw1su2h0r.jpg
#   inflating: data/6r7m8ku9es.jpg
#   inflating: data/6rkezdhma8.jpg
#   inflating: data/6sp0wd7hk3.jpg
#   inflating: data/6sq4gjcyiz.jpg
#   inflating: data/6ub9qf1jwn.jpg
#   inflating: data/6v1cxspbzq.jpg
#   inflating: data/6v3ipghnlc.jpg
#   inflating: data/6w194bklhi.jpg
#   inflating: data/6w1ym9jerf.jpg
#   inflating: data/6wh7ygoqis.jpg
#   inflating: data/6wrqi8ezan.jpg
#   inflating: data/6xgb3nofj0.jpg
#   inflating: data/6xpm9ijoh4.jpg
#   inflating: data/6y2g4zn701.jpg
#   inflating: data/6yrugso0tw.jpg
#   inflating: data/6yvsjl3tb4.jpg
#   inflating: data/70p3db6mnt.jpg
#   inflating: data/70wzcgx3fm.jpg
#   inflating: data/713yghkidx.jpg
#   inflating: data/71moswf85d.jpg
#   inflating: data/71qxlzfrd4.jpg
#   inflating: data/72auvi8oye.jpg
#   inflating: data/72isl14kn9.jpg
#   inflating: data/72k0v5cjox.jpg
#   inflating: data/735gqwclov.jpg
#   inflating: data/73dfup40bj.jpg
#   inflating: data/73ye0lkw1g.jpg
#   inflating: data/745f9kaumw.jpg
#   inflating: data/74gzbm9r3j.jpg
#   inflating: data/74j8wsaepr.jpg
#   inflating: data/751qgzdves.jpg
#   inflating: data/786ioag1u5.jpg
#   inflating: data/79rhbl31xe.jpg
#   inflating: data/7acoxuz95y.jpg
#   inflating: data/7atixbyj3o.jpg
#   inflating: data/7b6xvqj3zp.jpg
#   inflating: data/7b8ejfau52.jpg
#   inflating: data/7b8m1lxnyz.jpg
#   inflating: data/7bd5rgnem3.jpg
#   inflating: data/7bwyo82k53.jpg
#   inflating: data/7c1elmvr8d.jpg
#   inflating: data/7ch3afwv40.jpg
#   inflating: data/7d3ce5x9zo.jpg
#   inflating: data/7d4ljiyf0u.jpg
#   inflating: data/7dwz1uabrq.jpg
#   inflating: data/7e2gpbayzn.jpg
#   inflating: data/7ehd8z9wmj.jpg
#   inflating: data/7fmec18ds6.jpg
#   inflating: data/7fve9dspb0.jpg
#   inflating: data/7gb6pamit8.jpg
#   inflating: data/7hbu1t0qri.jpg
#   inflating: data/7kl2efju0z.jpg
#   inflating: data/7m94tnvze5.jpg
#   inflating: data/7nk4tehbil.jpg
#   inflating: data/7o5kc41zsj.jpg
#   inflating: data/7omq8vwl04.jpg
#   inflating: data/7omu1phtfw.jpg
#   inflating: data/7p5qb6i82m.jpg
#   inflating: data/7pcasxfwe6.jpg
#   inflating: data/7pe9jwq84x.jpg
#   inflating: data/7pir95fmxy.jpg
#   inflating: data/7ply36k5qm.jpg
#   inflating: data/7pz3fyhw8t.jpg
#   inflating: data/7s51m4vpr3.jpg
#   inflating: data/7sjyu98al3.jpg
#   inflating: data/7smzybq89e.jpg
#   inflating: data/7t9vkoc2pz.jpg
#   inflating: data/7tl31zpuyg.jpg
#   inflating: data/7tnc5jmp2w.jpg
#   inflating: data/7uerqn80km.jpg
#   inflating: data/7ugfpnqvk3.jpg
#   inflating: data/7ugpqotjzc.jpg
#   inflating: data/7ul5v2gzmi.jpg
#   inflating: data/7v3tgx4bd5.jpg
#   inflating: data/7vj8cfwtgz.jpg
#   inflating: data/7xqltwyu2c.jpg
#   inflating: data/7yqzgtuf51.jpg
#   inflating: data/7z53qtv28j.jpg
#   inflating: data/7zn2ew58ot.jpg
#   inflating: data/7zxad3oc6n.jpg
#   inflating: data/8096orcwb7.jpg
#   inflating: data/816idz2eg4.jpg
#   inflating: data/82yvo75zqx.jpg
#   inflating: data/83hvr51w6g.jpg
#   inflating: data/83labsnow2.jpg
#   inflating: data/84v5ui7bx3.jpg
#   inflating: data/86fch2t1s7.jpg
#   inflating: data/86k7lz1i3d.jpg
#   inflating: data/87k9b1tnwe.jpg
#   inflating: data/87vbakz9gw.jpg
#   inflating: data/8apt9hu4rs.jpg
#   inflating: data/8b7fj6cqh2.jpg
#   inflating: data/8blaev976r.jpg
#   inflating: data/8borky4jvf.jpg
#   inflating: data/8bsn9wyqhv.jpg
#   inflating: data/8c2uw5prkd.jpg
#   inflating: data/8cb1ma9rzh.jpg
#   inflating: data/8czytpboil.jpg
#   inflating: data/8dgjwrzb0o.jpg
#   inflating: data/8dlnvz3hoq.jpg
#   inflating: data/8dnk5j62qc.jpg
#   inflating: data/8e12fhwlsu.jpg
#   inflating: data/8ekqg1j450.jpg
#   inflating: data/8fd0qkbhiv.jpg
#   inflating: data/8hak6n7cfv.jpg
#   inflating: data/8i1afv6cmz.jpg
#   inflating: data/8j346nlemt.jpg
#   inflating: data/8ju6wbpc97.jpg
#   inflating: data/8k9mz4ytfb.jpg
#   inflating: data/8l27yrkwqm.jpg
#   inflating: data/8lcp4yodei.jpg
#   inflating: data/8lgh6tnrmf.jpg
#   inflating: data/8m0rwzjbht.jpg
#   inflating: data/8mp2y0n5gf.jpg
#   inflating: data/8ne7jmo9u4.jpg
#   inflating: data/8nz4tmr7kp.jpg
#   inflating: data/8o3rfdetnl.jpg
#   inflating: data/8p0mzl9den.jpg
#   inflating: data/8pe64nw3qd.jpg
#   inflating: data/8pjkqhw6rg.jpg
#   inflating: data/8q7103xz24.jpg
#   inflating: data/8qc6xka07u.jpg
#   inflating: data/8qxyeg4dmn.jpg
#   inflating: data/8r2bdnhsm5.jpg
#   inflating: data/8sgfjwaq5v.jpg
#   inflating: data/8si0wlpuk1.jpg
#   inflating: data/8tycj6gfzq.jpg
#   inflating: data/8uamro2nch.jpg
#   inflating: data/8vbapirnk9.jpg
#   inflating: data/8vwsa94r2c.jpg
#   inflating: data/8wjtkzyg73.jpg
#   inflating: data/8wm1vegx6u.jpg
#   inflating: data/8wnz6t14cd.jpg
#   inflating: data/8xbjve4m96.jpg
#   inflating: data/8yqvnu10tf.jpg
#   inflating: data/8zw34xh7sm.jpg
#   inflating: data/905ixmp3kb.jpg
#   inflating: data/91mqhdo0al.jpg
#   inflating: data/91q3vhg7yb.jpg
#   inflating: data/91vtr5q8yw.jpg
#   inflating: data/920w4vzxyd.jpg
#   inflating: data/93q4ezcbo6.jpg
#   inflating: data/94xm20loun.jpg
#   inflating: data/96gcnuz3lm.jpg
#   inflating: data/96jk237rpo.jpg
#   inflating: data/96qahzepwy.jpg
#   inflating: data/96qs4uianl.jpg
#   inflating: data/96s3t71azm.jpg
#   inflating: data/96w1lsatxu.jpg
#   inflating: data/976z1okqsi.jpg
#   inflating: data/97ce0yjsq8.jpg
#   inflating: data/980xodeavj.jpg
#   inflating: data/98uhpvlfni.jpg
#   inflating: data/9a4ryif2xc.jpg
#   inflating: data/9aczodugf4.jpg
#   inflating: data/9asthwiouk.jpg
#   inflating: data/9b65vjus28.jpg
#   inflating: data/9behtc6usp.jpg
#   inflating: data/9cdfb7ezi8.jpg
#   inflating: data/9cmg8zjqw0.jpg
#   inflating: data/9cnwe1lij6.jpg
#   inflating: data/9dejskrapn.jpg
#   inflating: data/9dn2gl81jf.jpg
#   inflating: data/9dwv7qzc2j.jpg
#   inflating: data/9e4d025avw.jpg
#   inflating: data/9ekgzwyp81.jpg
#   inflating: data/9emabilzjy.jpg
#   inflating: data/9f7dkaqw63.jpg
#   inflating: data/9fciv6nbap.jpg
#   inflating: data/9g5sbqxvj2.jpg
#   inflating: data/9gdj4pk5t2.jpg
#   inflating: data/9gdxjkpmfi.jpg
#   inflating: data/9gnia4zrl7.jpg
#   inflating: data/9gp27lioxw.jpg
#   inflating: data/9grlopjwtu.jpg
#   inflating: data/9h257z31pc.jpg
#   inflating: data/9hpl18m5sv.jpg
#   inflating: data/9kgiqzj17d.jpg
#   inflating: data/9lcrqfjb5h.jpg
#   inflating: data/9lm34anut8.jpg
#   inflating: data/9lym4ikfud.jpg
#   inflating: data/9m5ws16hiq.jpg
#   inflating: data/9mibzng6w8.jpg
#   inflating: data/9mzbrqly6x.jpg
#   inflating: data/9n726loid8.jpg
#   inflating: data/9nkv3mx1py.jpg
#   inflating: data/9op25q8awv.jpg
#   inflating: data/9oq2agxm46.jpg
#   inflating: data/9or1twqh06.jpg
#   inflating: data/9p7hk5js3m.jpg
#   inflating: data/9pkz40oquj.jpg
#   inflating: data/9qr3y8t7b4.jpg
#   inflating: data/9qrse3z2pc.jpg
#   inflating: data/9r3emn1tjy.jpg
#   inflating: data/9saepkyoud.jpg
#   inflating: data/9stfkuldec.jpg
#   inflating: data/9suwm26rgz.jpg
#   inflating: data/9tex4p2aj8.jpg
#   inflating: data/9tirxpf3u2.jpg
#   inflating: data/9xbchwtegu.jpg
#   inflating: data/9xtuim10gj.jpg
#   inflating: data/9y5g7hs28o.jpg
#   inflating: data/9y7sv8xqc2.jpg
#   inflating: data/9yegr5ltuv.jpg
#   inflating: data/9yos7ch31n.jpg
#   inflating: data/9ysu1fcodk.jpg
#   inflating: data/9zmjrkpvxq.jpg
#   inflating: data/a076wnrgiz.jpg
#   inflating: data/a098u7fyod.jpg
#   inflating: data/a1mxo96lnr.jpg
#   inflating: data/a1pr5fntdq.jpg
#   inflating: data/a2z57xc4jf.jpg
#   inflating: data/a3gncx1vj8.jpg
#   inflating: data/a475z3it0c.jpg
#   inflating: data/a53sohwtln.jpg
#   inflating: data/a6wkd2ipfo.jpg
#   inflating: data/a75mgw4n0q.jpg
#   inflating: data/a78wp9bm56.jpg
#   inflating: data/a7e0ohzlr4.jpg
#   inflating: data/a7qzs8ct4u.jpg
#   inflating: data/a87q3bepnj.jpg
#   inflating: data/a8cl2j4ge9.jpg
#   inflating: data/a9kxm1dvc8.jpg
#   inflating: data/abn7swh58l.jpg
#   inflating: data/acyjhobxmg.jpg
#   inflating: data/ae7udy4p59.jpg
#   inflating: data/afx3pqtshe.jpg
#   inflating: data/agj4spqzex.jpg
#   inflating: data/ahx6wi2lz1.jpg
#   inflating: data/aj23918mle.jpg
#   inflating: data/ajzs6h1pn2.jpg
#   inflating: data/ak7oh5yqcn.jpg
#   inflating: data/akqw6ugcb3.jpg
#   inflating: data/alqkcy1gxo.jpg
#   inflating: data/aobskuzt4f.jpg
#   inflating: data/aohw7c4gyt.jpg
#   inflating: data/aou8vrskcw.jpg
#   inflating: data/apbx9wfyej.jpg
#   inflating: data/aq82wxf7e5.jpg
#   inflating: data/aqkgo7b3cn.jpg
#   inflating: data/aqwr8lx4gh.jpg
#   inflating: data/ar38hlz16g.jpg
#   inflating: data/arqzi9ojyu.jpg
#   inflating: data/at06dxb5uf.jpg
#   inflating: data/atdn0ucrev.jpg
#   inflating: data/atfmueqpwg.jpg
#   inflating: data/atso23mhix.jpg
#   inflating: data/atvix0fwnq.jpg
#   inflating: data/au51dlkvj8.jpg
#   inflating: data/av37tm40xq.jpg
#   inflating: data/av576ciy24.jpg
#   inflating: data/aw15o7zhqj.jpg
#   inflating: data/ay1ojmncef.jpg
#   inflating: data/ayezh6x1l7.jpg
#   inflating: data/az0b2vf84i.jpg
#   inflating: data/azrm16swlc.jpg
#   inflating: data/b0zyo46l8j.jpg
#   inflating: data/b1d6yjg2s9.jpg
#   inflating: data/b3dxt9i082.jpg
#   inflating: data/b68loqufk1.jpg
#   inflating: data/b6e3fr42op.jpg
#   inflating: data/b6nd7w49yu.jpg
#   inflating: data/b6xcngshzv.jpg
#   inflating: data/b8fmiexjvt.jpg
#   inflating: data/baku276tdm.jpg
#   inflating: data/bc1lwy746q.jpg
#   inflating: data/bc4szm862v.jpg
#   inflating: data/bcxa3245m6.jpg
#   inflating: data/bd2ex9vzit.jpg
#   inflating: data/bg8wv2hfse.jpg
#   inflating: data/bgndar2653.jpg
#   inflating: data/bgu708rvea.jpg
#   inflating: data/bgufami6hn.jpg
#   inflating: data/bgwtk4fx1y.jpg
#   inflating: data/bif6ayhjm1.jpg
#   inflating: data/bj9tr08eoi.jpg
#   inflating: data/bjq6nfldhp.jpg
#   inflating: data/bkmc3ufr4d.jpg
#   inflating: data/bkz57ew34g.jpg
#   inflating: data/bm2detzing.jpg
#   inflating: data/bm2kodr7hn.jpg
#   inflating: data/bo60lf4xgw.jpg
#   inflating: data/boi7lua65j.jpg
#   inflating: data/bpa2gctuoy.jpg
#   inflating: data/bprjgest20.jpg
#   inflating: data/bptqgijd5m.jpg
#   inflating: data/br1mxvs4wy.jpg
#   inflating: data/brhtju6dwl.jpg
#   inflating: data/bro8zmsce3.jpg
#   inflating: data/bsj3yf0q5a.jpg
#   inflating: data/bu7ik1gj63.jpg
#   inflating: data/buew46j70c.jpg
#   inflating: data/buf13ed58p.jpg
#   inflating: data/bvdehskxrq.jpg
#   inflating: data/bvp9dksyqa.jpg
#   inflating: data/bw5xm8o7y0.jpg
#   inflating: data/bwvq2jyt6k.jpg
#   inflating: data/bwzex3s1nh.jpg
#   inflating: data/bx8g51rnfw.jpg
#   inflating: data/by0ok4fxzl.jpg
#   inflating: data/byil0spw34.jpg
#   inflating: data/bz0kw2u41q.jpg
#   inflating: data/bzg6j9rw2v.jpg
#   inflating: data/bzkli15mp3.jpg
#   inflating: data/c0dxgf241y.jpg
#   inflating: data/c0l6gp5kan.jpg
#   inflating: data/c0p1uheoa2.jpg
#   inflating: data/c1ba5t8o92.jpg
#   inflating: data/c1h5r96ls8.jpg
#   inflating: data/c1j45xfzn0.jpg
#   inflating: data/c2a4j8yp50.jpg
#   inflating: data/c35m7s2oup.jpg
#   inflating: data/c36owaezhg.jpg
#   inflating: data/c3jnp4tzwg.jpg
#   inflating: data/c4aoxdr01i.jpg
#   inflating: data/c4dvmbg71f.jpg
#   inflating: data/c4ib03vhu8.jpg
#   inflating: data/c4ubsjwniy.jpg
#   inflating: data/c5arzvbl9o.jpg
#   inflating: data/c5mq78lotn.jpg
#   inflating: data/c6ahzjivgf.jpg
#   inflating: data/c6e7pb40ka.jpg
#   inflating: data/c70rjnpzv2.jpg
#   inflating: data/c7gkvlqb0o.jpg
#   inflating: data/c7m14g6rv2.jpg
#   inflating: data/c8ljawbk2e.jpg
#   inflating: data/c94qdzx2r0.jpg
#   inflating: data/c9h2wi3fmu.jpg
#   inflating: data/c9l7ifzox6.jpg
#   inflating: data/c9qztk7e6n.jpg
#   inflating: data/c9s8mk7qb1.jpg
#   inflating: data/ca9zmxwgn1.jpg
#   inflating: data/caw74fr85s.jpg
#   inflating: data/cb7q02djin.jpg
#   inflating: data/cbinfhqu52.jpg
#   inflating: data/cbolq7kusr.jpg
#   inflating: data/cd8eao36q1.jpg
#   inflating: data/cdl87xvigj.jpg
#   inflating: data/ce7bt2hqgw.jpg
#   inflating: data/ceqla6dbhk.jpg
#   inflating: data/cfxu2etmd3.jpg
#   inflating: data/ch287fbnt5.jpg
#   inflating: data/ch6am7ox8b.jpg
#   inflating: data/ci2kay7bxh.jpg
#   inflating: data/ciy9g5u6qm.jpg
#   inflating: data/cjtuf520e9.jpg
#   inflating: data/ck6msi4y9l.jpg
#   inflating: data/ckjfi4d2xe.jpg
#   inflating: data/ckmr1ivqot.jpg
#   inflating: data/clesxni0qj.jpg
#   inflating: data/clfjra2v7o.jpg
#   inflating: data/clhk6o2nxz.jpg
#   inflating: data/cmoxga5uye.jpg
#   inflating: data/cmr3f4s8he.jpg
#   inflating: data/cmsbgpvzn1.jpg
#   inflating: data/cmxpdeq2y0.jpg
#   inflating: data/cn7mhqkb39.jpg
#   inflating: data/cnk49yz1ui.jpg
#   inflating: data/co3k4jhsyx.jpg
#   inflating: data/co70xj3ge8.jpg
#   inflating: data/cohydrglfv.jpg
#   inflating: data/cplxhw6ek0.jpg
#   inflating: data/cqe8nm21xb.jpg
#   inflating: data/cquods1her.jpg
#   inflating: data/cr0hiywvua.jpg
#   inflating: data/cr1nqm3zx9.jpg
#   inflating: data/cr9m2pteoy.jpg
#   inflating: data/crbfd3hi0o.jpg
#   inflating: data/crilf5enta.jpg
#   inflating: data/ctv3fjpqmh.jpg
#   inflating: data/ctvo5egaj8.jpg
#   inflating: data/cutrjadfbe.jpg
#   inflating: data/cv7q49okdb.jpg
#   inflating: data/cvq3kjy812.jpg
#   inflating: data/cwb9yxl5og.jpg
#   inflating: data/cwhpj7uxv4.jpg
#   inflating: data/cxwrq10mal.jpg
#   inflating: data/cygwl39k7d.jpg
#   inflating: data/cz0jdkr6h9.jpg
#   inflating: data/czw9ludry5.jpg
#   inflating: data/d12cymg8fo.jpg
#   inflating: data/d1bups6jy7.jpg
#   inflating: data/d2skcf6qj0.jpg
#   inflating: data/d2xcprsjmq.jpg
#   inflating: data/d3bflyj6es.jpg
#   inflating: data/d3vihwky70.jpg
#   inflating: data/d42kyl86ae.jpg
#   inflating: data/d4jbnrxowm.jpg
#   inflating: data/d5oszlyvtn.jpg
#   inflating: data/d7qktgcmp0.jpg
#   inflating: data/d86mo41piu.jpg
#   inflating: data/d94e8f2t0y.jpg
#   inflating: data/d9wv7s4ogc.jpg
#   inflating: data/dawtgnr3jh.jpg
#   inflating: data/dbjq1zwkay.jpg
#   inflating: data/dbzy0jn8oe.jpg
#   inflating: data/dc569pbi73.jpg
#   inflating: data/dcvb9tfwa3.jpg
#   inflating: data/debpqcmr2j.jpg
#   inflating: data/df310e9rgx.jpg
#   inflating: data/dfix4s68k1.jpg
#   inflating: data/dgjyl45eta.jpg
#   inflating: data/dhc3uy8pas.jpg
#   inflating: data/dhnbmwe83g.jpg
#   inflating: data/dhni5ryaue.jpg
#   inflating: data/dika3b79vm.jpg
#   inflating: data/dil4hoyu57.jpg
#   inflating: data/dj2ef18ns0.jpg
#   inflating: data/dj7brs8oc4.jpg
#   inflating: data/dj7ts985m2.jpg
#   inflating: data/djwx65nypa.jpg
#   inflating: data/dkj0l3w42m.jpg
#   inflating: data/dkyjte6xbz.jpg
#   inflating: data/dmjfravkqo.jpg
#   inflating: data/dmkrnea8xl.jpg
#   inflating: data/dmnkrj3wsy.jpg
#   inflating: data/dnkx23t4l0.jpg
#   inflating: data/dnlfqi2oxu.jpg
#   inflating: data/dojy76xpz0.jpg
#   inflating: data/dopgjwmk4h.jpg
#   inflating: data/dotn26v83u.jpg
#   inflating: data/dovsjhtupi.jpg
#   inflating: data/dp0mcb54wo.jpg
#   inflating: data/dpz5aoh7k2.jpg
#   inflating: data/dpzw7gs8af.jpg
#   inflating: data/dqhk25ylvs.jpg
#   inflating: data/dqy7p98r6b.jpg
#   inflating: data/dr53w9aogj.jpg
#   inflating: data/dsfrzlhijy.jpg
#   inflating: data/dsm74x9upy.jpg
#   inflating: data/dsqn5iemuj.jpg
#   inflating: data/dt172rusfy.jpg
#   inflating: data/du5yvhek2g.jpg
#   inflating: data/duc9o38q67.jpg
#   inflating: data/dun0grjwb2.jpg
#   inflating: data/dun86e9x2s.jpg
#   inflating: data/dupnmqae62.jpg
#   inflating: data/dvyp5lr7zn.jpg
#   inflating: data/dxlzoym0wk.jpg
#   inflating: data/dxu71sivlo.jpg
#   inflating: data/dxv5zfe7qn.jpg
#   inflating: data/dy75qjoecw.jpg
#   inflating: data/dyk3prs289.jpg
#   inflating: data/dyw6jagi1l.jpg
#   inflating: data/dywmsqet2l.jpg
#   inflating: data/dz6185v3yb.jpg
#   inflating: data/dzcoxpkt0g.jpg
#   inflating: data/dzerfmji2n.jpg
#   inflating: data/dzwupx3lsb.jpg
#   inflating: data/dzxflg07yu.jpg
#   inflating: data/e0xw97o18r.jpg
#   inflating: data/e10ftm364s.jpg
#   inflating: data/e24wptzk3g.jpg
#   inflating: data/e25ibj48wz.jpg
#   inflating: data/e5g7qz1ojr.jpg
#   inflating: data/e5w4tvp82k.jpg
#   inflating: data/e5yusoh287.jpg
#   inflating: data/e6mbk9qrhz.jpg
#   inflating: data/e7vqtr3fw4.jpg
#   inflating: data/e81wtuhipc.jpg
#   inflating: data/e8soz0ldnk.jpg
#   inflating: data/e8vxag7m2p.jpg
#   inflating: data/e9jhyfd1l3.jpg
#   inflating: data/ebguj8d9of.jpg
#   inflating: data/ebyk9ncgfu.jpg
#   inflating: data/ecakwboqv9.jpg
#   inflating: data/ecdlfj85aq.jpg
#   inflating: data/edqpj7lc9w.jpg
#   inflating: data/ef1hxjb78k.jpg
#   inflating: data/eflc59auo1.jpg
#   inflating: data/efqdjakt2b.jpg
#   inflating: data/eftr73k51n.jpg
#   inflating: data/efwqhkrutj.jpg
#   inflating: data/egb3lao857.jpg
#   inflating: data/egpvrou3d7.jpg
#   inflating: data/ehd26rgoq0.jpg
#   inflating: data/ehu1cb8rx3.jpg
#   inflating: data/eikbvn7jmu.jpg
#   inflating: data/eiomujzwpc.jpg
#   inflating: data/ejzbtvr415.jpg
#   inflating: data/ejzc6fqy7m.jpg
#   inflating: data/ek04buavnw.jpg
#   inflating: data/ekilyuds31.jpg
#   inflating: data/ekocst68zm.jpg
#   inflating: data/ekrsxihf6w.jpg
#   inflating: data/ektm9fqixw.jpg
#   inflating: data/el1audwz4v.jpg
#   inflating: data/elkqvdsnz9.jpg
#   inflating: data/emzhfwkv5s.jpg
#   inflating: data/ent5160voj.jpg
#   inflating: data/eo17mysb5a.jpg
#   inflating: data/ep8j1kgmr3.jpg
#   inflating: data/epb1slk5vc.jpg
#   inflating: data/eqm1tx2069.jpg
#   inflating: data/ervm2c3sgw.jpg
#   inflating: data/es6thuqfb3.jpg
#   inflating: data/eto5s6pck3.jpg
#   inflating: data/ew4it5ofly.jpg
#   inflating: data/ex60y4qdzl.jpg
#   inflating: data/extk6s0w4l.jpg
#   inflating: data/ez3jfhi6w7.jpg
#   inflating: data/ezb0rh8u9k.jpg
#   inflating: data/ezf548thpk.jpg
#   inflating: data/eznm5d8y2k.jpg
#   inflating: data/f03navzmgx.jpg
#   inflating: data/f04i239syj.jpg
#   inflating: data/f1j8zsmvoh.jpg
#   inflating: data/f1o3x6s2n0.jpg
#   inflating: data/f1p2dc4a9b.jpg
#   inflating: data/f1qxij2g7z.jpg
#   inflating: data/f2awn5ovbr.jpg
#   inflating: data/f2ctg7am8n.jpg
#   inflating: data/f2ery9c57l.jpg
#   inflating: data/f38ismvaw9.jpg
#   inflating: data/f5snyu1k3v.jpg
#   inflating: data/f68z915x40.jpg
#   inflating: data/f6qwen3jub.jpg
#   inflating: data/f97e0ia5yq.jpg
#   inflating: data/f9gwqy2o1i.jpg
#   inflating: data/f9px3ngvdo.jpg
#   inflating: data/fa1c0jnh4x.jpg
#   inflating: data/fahwlr9cnu.jpg
#   inflating: data/fb0xpjqrng.jpg
#   inflating: data/fbhmo7u3t1.jpg
#   inflating: data/fcailxtgyh.jpg
#   inflating: data/fcqvoh341t.jpg
#   inflating: data/fdlsrbpn6c.jpg
#   inflating: data/fdu860m1qp.jpg
#   inflating: data/fhxet2n8zq.jpg
#   inflating: data/fi4puxkgel.jpg
#   inflating: data/fikgmoh8qe.jpg
#   inflating: data/finhpu42jd.jpg
#   inflating: data/fjadmcgl41.jpg
#   inflating: data/fjqnux9goh.jpg
#   inflating: data/fjznri15b4.jpg
#   inflating: data/fk39h1p4oa.jpg
#   inflating: data/fk7d8lg1vw.jpg
#   inflating: data/fl49dcj60u.jpg
#   inflating: data/fladmy8sg2.jpg
#   inflating: data/fln5apgiu6.jpg
#   inflating: data/fm0itkjurl.jpg
#   inflating: data/fmin1doukr.jpg
#   inflating: data/fmlduinej5.jpg
#   inflating: data/fn8ue5t4ap.jpg
#   inflating: data/fot93imz1j.jpg
#   inflating: data/fp1gkw2u93.jpg
#   inflating: data/fpcvgs20mw.jpg
#   inflating: data/fpkuxs2bv7.jpg
#   inflating: data/frajd51omh.jpg
#   inflating: data/frmp6b1lqu.jpg
#   inflating: data/frvu65iwbj.jpg
#   inflating: data/fskpgzn3qj.jpg
#   inflating: data/fsrk4cpo31.jpg
#   inflating: data/ftxyp7ma6n.jpg
#   inflating: data/fu7tazsdly.jpg
#   inflating: data/fuq0re67d2.jpg
#   inflating: data/fvqerd4c0l.jpg
#   inflating: data/fwihzlqe7b.jpg
#   inflating: data/fwnkx53drh.jpg
#   inflating: data/fxkjmy27s1.jpg
#   inflating: data/fynkvhj7ws.jpg
#   inflating: data/fz20dxla45.jpg
#   inflating: data/fzvcrp8qd1.jpg
#   inflating: data/fzy0gind52.jpg
#   inflating: data/g06y4dovqm.jpg
#   inflating: data/g0qr15bjsc.jpg
#   inflating: data/g13mhbxw24.jpg
#   inflating: data/g28oe73f14.jpg
#   inflating: data/g3dm80ihl1.jpg
#   inflating: data/g4bfk75vse.jpg
#   inflating: data/g4fmwbo16c.jpg
#   inflating: data/g4h79n0pte.jpg
#   inflating: data/g4mevpylri.jpg
#   inflating: data/g4qtx1rf5b.jpg
#   inflating: data/g4xrps8mvw.jpg
#   inflating: data/g5tf0vy7b4.jpg
#   inflating: data/g6dau8wo5z.jpg
#   inflating: data/g861hjq0eo.jpg
#   inflating: data/g86p97ro3x.jpg
#   inflating: data/g87kq9h0ud.jpg
#   inflating: data/g8f2c0m4lk.jpg
#   inflating: data/g8oxv0picu.jpg
#   inflating: data/gaejc2x1yv.jpg
#   inflating: data/gakfqev36t.jpg
#   inflating: data/gauokjep8f.jpg
#   inflating: data/gbr8o6p2zs.jpg
#   inflating: data/gbrkmywx7t.jpg
#   inflating: data/gce2hnk9p0.jpg
#   inflating: data/gcoljt4k8x.jpg
#   inflating: data/gcwujzvh28.jpg
#   inflating: data/ge18s4wp56.jpg
#   inflating: data/gezkvuy0o1.jpg
#   inflating: data/gfdtk9amx3.jpg
#   inflating: data/gfhsr02ijw.jpg
#   inflating: data/gh1alfj0np.jpg
#   inflating: data/ghk6ds48ma.jpg
#   inflating: data/ghzbrw3oek.jpg
#   inflating: data/giexlnho16.jpg
#   inflating: data/gilsw5xp3f.jpg
#   inflating: data/gj0hdualbf.jpg
#   inflating: data/gjfuxspn4z.jpg
#   inflating: data/gjno8qrtpk.jpg
#   inflating: data/gk94th31c6.jpg
#   inflating: data/gkm6q8edlf.jpg
#   inflating: data/gkvefw39ym.jpg
#   inflating: data/gl1iujwoc3.jpg
#   inflating: data/glfynq1p7i.jpg
#   inflating: data/glncqif729.jpg
#   inflating: data/gm0phedti6.jpg
#   inflating: data/gmkira4nzj.jpg
#   inflating: data/gmu5bwcd98.jpg
#   inflating: data/gnq2s8olrz.jpg
#   inflating: data/gntcoebrqa.jpg
#   inflating: data/go5c01aq3t.jpg
#   inflating: data/go7r4mdlxp.jpg
#   inflating: data/goyhzv1pmb.jpg
#   inflating: data/gpbcinw462.jpg
#   inflating: data/gpzbme2adt.jpg
#   inflating: data/gr8hxnsmju.jpg
#   inflating: data/grlqzhnyok.jpg
#   inflating: data/gs9wqtdm5p.jpg
#   inflating: data/gsd4y3xcf5.jpg
#   inflating: data/gt17uawrl5.jpg
#   inflating: data/gtay86v4b1.jpg
#   inflating: data/gtjxz6e5co.jpg
#   inflating: data/gtwmer0l4n.jpg
#   inflating: data/gtzbudeivx.jpg
#   inflating: data/gu1wyodfr4.jpg
#   inflating: data/gu39d8ealw.jpg
#   inflating: data/gue5rkfvcw.jpg
#   inflating: data/gvpe7x8h69.jpg
#   inflating: data/gx30a61mz2.jpg
#   inflating: data/gxbmepi5r0.jpg
#   inflating: data/gxu3rhn1bf.jpg
#   inflating: data/gyo9qmtarb.jpg
#   inflating: data/gz0qbojfxh.jpg
#   inflating: data/gzfpsk87mn.jpg
#   inflating: data/h0c6kgzu2b.jpg
#   inflating: data/h0p18vl6fr.jpg
#   inflating: data/h10j36uy92.jpg
#   inflating: data/h1ekiumf89.jpg
#   inflating: data/h2ilu45qn1.jpg
#   inflating: data/h2k8573apr.jpg
#   inflating: data/h2qk0uiwxf.jpg
#   inflating: data/h2zeodtbw4.jpg
#   inflating: data/h36xio2yun.jpg
#   inflating: data/h4wpfruq82.jpg
#   inflating: data/h5bx9jv63s.jpg
#   inflating: data/h649ynrtlq.jpg
#   inflating: data/h64sxmupyk.jpg
#   inflating: data/h6fqlrj1xv.jpg
#   inflating: data/h8fqwtmz93.jpg
#   inflating: data/h8m62b9jkl.jpg
#   inflating: data/h8q6mjt0kd.jpg
#   inflating: data/h8y4mi10qn.jpg
#   inflating: data/hakv49umqs.jpg
#   inflating: data/hanwjkuvzi.jpg
#   inflating: data/hatm23fb94.jpg
#   inflating: data/hbrmx1o8sv.jpg
#   inflating: data/hbt1u8cgqi.jpg
#   inflating: data/hc48mgfuei.jpg
#   inflating: data/hc5rl72an4.jpg
#   inflating: data/hcmxv6lowe.jpg
#   inflating: data/hcsgd5uvyp.jpg
#   inflating: data/he5gjk6m3p.jpg
#   inflating: data/heqoycvwp0.jpg
#   inflating: data/hfe7rqdu52.jpg
#   inflating: data/hfyk9wvsxa.jpg
#   inflating: data/hfyw5g6a1k.jpg
#   inflating: data/hia3lf4sjd.jpg
#   inflating: data/hj3c5f8mkd.jpg
#   inflating: data/hk5tisp1mr.jpg
#   inflating: data/hlja4qfiv3.jpg
#   inflating: data/hmlj0ugqxt.jpg
#   inflating: data/hn7yg9elbj.jpg
#   inflating: data/hnj4flyoru.jpg
#   inflating: data/horgyf4m3q.jpg
#   inflating: data/hpm9ux7qe3.jpg
#   inflating: data/hprzm6g2l4.jpg
#   inflating: data/hpyzt8gdwo.jpg
#   inflating: data/hqme9pb6v2.jpg
#   inflating: data/hrc97on1zx.jpg
#   inflating: data/hsxm2jv71o.jpg
#   inflating: data/hszf7v5tui.jpg
#   inflating: data/hul6wfodyk.jpg
#   inflating: data/hv9m5j20cr.jpg
#   inflating: data/hw1j6q8tox.jpg
#   inflating: data/hy7i46w2qd.jpg
#   inflating: data/hza1p7umoe.jpg
#   inflating: data/hzj03fwpnb.jpg
#   inflating: data/i0hv8t193j.jpg
#   inflating: data/i0pa34tsgm.jpg
#   inflating: data/i256acudp8.jpg
#   inflating: data/i2f4x1jw7n.jpg
#   inflating: data/i32htf7rua.jpg
#   inflating: data/i4gvt98pmf.jpg
#   inflating: data/i4oeb980pu.jpg
#   inflating: data/i4txfn51vc.jpg
#   inflating: data/i4yt8j7bgl.jpg
#   inflating: data/i70dyc13pu.jpg
#   inflating: data/i723kbzohc.jpg
#   inflating: data/i8abutrcz2.jpg
#   inflating: data/i8qr01seyx.jpg
#   inflating: data/i8zhjl6awn.jpg
#   inflating: data/i97lxag30z.jpg
#   inflating: data/i9fnxrg170.jpg
#   inflating: data/i9j38pbdaz.jpg
#   inflating: data/ib2srkuzn7.jpg
#   inflating: data/ibqj9xecpa.jpg
#   inflating: data/ibtero3ms6.jpg
#   inflating: data/id1qmeu2ks.jpg
#   inflating: data/idntqsry9c.jpg
#   inflating: data/ifnhte8wqs.jpg
#   inflating: data/igj8um9nbf.jpg
#   inflating: data/igqykm5l7t.jpg
#   inflating: data/igs1wo7qkj.jpg
#   inflating: data/igsdkhy2eu.jpg
#   inflating: data/igw1dypaot.jpg
#   inflating: data/ik026c5mvx.jpg
#   inflating: data/iknats6ufx.jpg
#   inflating: data/il84wysd0n.jpg
#   inflating: data/ilpcnh3m7v.jpg
#   inflating: data/inb5jgscot.jpg
#   inflating: data/ioh62pzxwt.jpg
#   inflating: data/iokf6mcrq2.jpg
#   inflating: data/ip4872akng.jpg
#   inflating: data/ipartmk5gy.jpg
#   inflating: data/iq9dog1skr.jpg
#   inflating: data/iqpg7j4au9.jpg
#   inflating: data/iqwcxahzbu.jpg
#   inflating: data/irlt370pa1.jpg
#   inflating: data/irxqdlm5zh.jpg
#   inflating: data/is7n8254rh.jpg
#   inflating: data/isfpa35971.jpg
#   inflating: data/it147s2axc.jpg
#   inflating: data/it3s850frc.jpg
#   inflating: data/itb01ryodm.jpg
#   inflating: data/iu06o91mjx.jpg
#   inflating: data/iu3cvdwa7p.jpg
#   inflating: data/iux4rvhce7.jpg
#   inflating: data/ivgqkwmds2.jpg
#   inflating: data/ivmdapy6lf.jpg
#   inflating: data/ivtnzhrdlu.jpg
#   inflating: data/ivxu4fwkc5.jpg
#   inflating: data/iwgz72d4tn.jpg
#   inflating: data/iwhp0271c6.jpg
#   inflating: data/ixgph4yve8.jpg
#   inflating: data/ixz2fmh8bw.jpg
#   inflating: data/iyu1mzhdce.jpg
#   inflating: data/izedjsquor.jpg
#   inflating: data/j05ykuc2ed.jpg
#   inflating: data/j12vlyn96c.jpg
#   inflating: data/j1yso54hl7.jpg
#   inflating: data/j2q83shyx6.jpg
#   inflating: data/j34emd928b.jpg
#   inflating: data/j3cyrza9fk.jpg
#   inflating: data/j3ldu4cvz5.jpg
#   inflating: data/j3yeqihsmw.jpg
#   inflating: data/j4bf0yv628.jpg
#   inflating: data/j4lcy6spqv.jpg
#   inflating: data/j4n5d1xrsh.jpg
#   inflating: data/j5y6u79ahe.jpg
#   inflating: data/j6qpndl9ts.jpg
#   inflating: data/j7xdriveow.jpg
#   inflating: data/j8l7rb6x2d.jpg
#   inflating: data/j8xwygreh0.jpg
#   inflating: data/j9lg4o3rsy.jpg
#   inflating: data/ja9crqih30.jpg
#   inflating: data/jal4ygxecq.jpg
#   inflating: data/jaxwvcefzl.jpg
#   inflating: data/jbkt70iyov.jpg
#   inflating: data/jcnek6tpyr.jpg
#   inflating: data/jdgbru6fy5.jpg
#   inflating: data/jdgiuf2atv.jpg
#   inflating: data/jdlvzi6w70.jpg
#   inflating: data/jfdk0nz7u1.jpg
#   inflating: data/jftnhexco3.jpg
#   inflating: data/jg981fqt0k.jpg
#   inflating: data/jgsdx4ofrl.jpg
#   inflating: data/jhe6u5mwp2.jpg
#   inflating: data/ji0o1h9plg.jpg
#   inflating: data/jki3m6h81s.jpg
#   inflating: data/jktye7hw5f.jpg
#   inflating: data/jmlezkuxg7.jpg
#   inflating: data/joa3nw02l5.jpg
#   inflating: data/jokl9ycut7.jpg
#   inflating: data/jpai2l9hfn.jpg
#   inflating: data/jr4co1upx6.jpg
#   inflating: data/jreu7hawcg.jpg
#   inflating: data/jt0sfa4wz8.jpg
#   inflating: data/juybmfx93w.jpg
#   inflating: data/jvz2i3gnt1.jpg
#   inflating: data/jwbr469soa.jpg
#   inflating: data/jwpt8ld3n4.jpg
#   inflating: data/jws60uqnec.jpg
#   inflating: data/jxywbciseg.jpg
#   inflating: data/jy4ms58fo3.jpg
#   inflating: data/jyqmzv45nb.jpg
#   inflating: data/jyugwxl9nq.jpg
#   inflating: data/jzlwcy1b95.jpg
#   inflating: data/jzq15rcxbe.jpg
#   inflating: data/jzskmofc6p.jpg
#   inflating: data/k0tisdpx2j.jpg
#   inflating: data/k1cqia2zo5.jpg
#   inflating: data/k2q6us3z17.jpg
#   inflating: data/k2qmgoxs8z.jpg
#   inflating: data/k2xvzyaltn.jpg
#   inflating: data/k40l7vaw3p.jpg
#   inflating: data/k43o7mg5qj.jpg
#   inflating: data/k4usoziyq3.jpg
#   inflating: data/k4w5v1orjz.jpg
#   inflating: data/k5rqsgp1u7.jpg
#   inflating: data/k7amfgqp65.jpg
#   inflating: data/k8iz6l9wft.jpg
#   inflating: data/k8mlxtzvho.jpg
#   inflating: data/k94dptf7eu.jpg
#   inflating: data/k9iwdoh8xz.jpg
#   inflating: data/k9rleh1oqd.jpg
#   inflating: data/ka73bvsgw4.jpg
#   inflating: data/kbpiqo43df.jpg
#   inflating: data/kcpuizryl3.jpg
#   inflating: data/kctujgf0e4.jpg
#   inflating: data/kdmarp5xj1.jpg
#   inflating: data/keh6g5lasq.jpg
#   inflating: data/ken0vxd7fp.jpg
#   inflating: data/kf3brigts5.jpg
#   inflating: data/kf65se24pu.jpg
#   inflating: data/kf680wgzpe.jpg
#   inflating: data/kgbl0y6c41.jpg
#   inflating: data/kgz46toidh.jpg
#   inflating: data/khaz78j9mf.jpg
#   inflating: data/khoba54v1q.jpg
#   inflating: data/kja4qcs2lx.jpg
#   inflating: data/kjo1np6xz2.jpg
#   inflating: data/kl3d5sj6p8.jpg
#   inflating: data/kluavs5gf0.jpg
#   inflating: data/klzx4pa8g3.jpg
#   inflating: data/kmfgnxc63p.jpg
#   inflating: data/kmurz63s1l.jpg
#   inflating: data/kol0dbpm34.jpg
# ...
#   inflating: data/spyj1k5r9z.jpg
#   inflating: data/spz1m2eu9i.jpg
#   inflating: data/sq4jl1xibn.jpg
#   inflating: data/sq5fwy2hga.jpg
#   inflating: data/sq5t0yoi27.jpg
#   inflating: data/srye1fa6c8.jpg
#   inflating: data/st1p3di097.jpg
#   inflating: data/styl072zag.jpg
#   inflating: data/su4akigqpr.jpg
#   inflating: data/su6va3qtxj.jpg
#   inflating: data/sv53ujcf9d.jpg
#   inflating: data/swa205jyun.jpg
#   inflating: data/swixut5b3l.jpg
#   inflating: data/swnvlfekd1.jpg
#   inflating: data/sxmynbr274.jpg
#   inflating: data/sxpke49az0.jpg
#   inflating: data/syr8ux9fg4.jpg
#   inflating: data/sz01dmrnew.jpg
#   inflating: data/szedxk2m39.jpg
#   inflating: data/t26js3x1oe.jpg
#   inflating: data/t2hz0g5uk7.jpg
#   inflating: data/t2jqorncwd.jpg
#   inflating: data/t2u5yhlsfw.jpg
#   inflating: data/t3a19egwoj.jpg
#   inflating: data/t4n0gb5fqd.jpg
#   inflating: data/t4nl8x0zgb.jpg
#   inflating: data/t5a8kuoil6.jpg
#   inflating: data/t5e3c8injg.jpg
#   inflating: data/t6d89h3fy2.jpg
#   inflating: data/t6un7lvw3y.jpg
#   inflating: data/t907cw3qg2.jpg
#   inflating: data/ta5v3sn0dw.jpg
#   inflating: data/tb5afsk6lr.jpg
#   inflating: data/tb5neawzl6.jpg
#   inflating: data/tbmcoe8wp5.jpg
#   inflating: data/tcoefd47n9.jpg
#   inflating: data/tcrnmkq8a9.jpg
#   inflating: data/tcsg7d58i3.jpg
#   inflating: data/tdybfg0ra5.jpg
#   inflating: data/tel124nj6s.jpg
#   inflating: data/teq5r1pnlv.jpg
#   inflating: data/tf3ecl7bv5.jpg
#   inflating: data/tfi3h87maj.jpg
#   inflating: data/tfxsw93hp0.jpg
#   inflating: data/tg54hnrxdp.jpg
#   inflating: data/thlb5vm2dk.jpg
#   inflating: data/ti4lrx075p.jpg
#   inflating: data/tjmexq84vh.jpg
#   inflating: data/tjp6v90b3s.jpg
#   inflating: data/tjyg0bhe3u.jpg
#   inflating: data/tk7mqp6rl0.jpg
#   inflating: data/tl3kcrdvof.jpg
#   inflating: data/tla2wv5u9o.jpg
#   inflating: data/tmd1p5iksf.jpg
#   inflating: data/tmu2wqb6zi.jpg
#   inflating: data/tn56aeowc1.jpg
#   inflating: data/tnlfmgi305.jpg
#   inflating: data/to14qjghyk.jpg
#   inflating: data/tou3f7pmi9.jpg
#   inflating: data/tpdhqy0mij.jpg
#   inflating: data/tpg2obxjc3.jpg
#   inflating: data/tpm8q6xo1k.jpg
#   inflating: data/tq5gae4sb3.jpg
#   inflating: data/tsd8mp3g69.jpg
#   inflating: data/tsmxauhpkr.jpg
#   inflating: data/tusvg61rz4.jpg
#   inflating: data/tw71lpib0s.jpg
#   inflating: data/tyo4s5rfwd.jpg
#   inflating: data/typ2q9sw0b.jpg
#   inflating: data/tzp5chyskx.jpg
#   inflating: data/u06tnmlfqg.jpg
#   inflating: data/u2j1svhxpg.jpg
#   inflating: data/u2owhad6c1.jpg
#   inflating: data/u31c6lixon.jpg
#   inflating: data/u34vhrwpjz.jpg
#   inflating: data/u3fel5a8xw.jpg
#   inflating: data/u3hv47ixz8.jpg
#   inflating: data/u3zlxmvyoh.jpg
#   inflating: data/u3zy6qmi85.jpg
#   inflating: data/u4o2qvys0r.jpg
#   inflating: data/u4stoagwp1.jpg
#   inflating: data/u56orj28pz.jpg
#   inflating: data/u624vjlhrm.jpg
#   inflating: data/u64mgvklxn.jpg
#   inflating: data/u6cfite01s.jpg
#   inflating: data/u7lfe2nsim.jpg
#   inflating: data/u8enxy02os.jpg
#   inflating: data/u8si09zra5.jpg
#   inflating: data/u9rkgts3ma.jpg
#   inflating: data/u9s8e1m4z0.jpg
#   inflating: data/uaeli2v5sy.jpg
#   inflating: data/uas572eblf.jpg
#   inflating: data/uav73jnzq8.jpg
#   inflating: data/ucbqs9j51z.jpg
#   inflating: data/ucm9b4d8gq.jpg
#   inflating: data/udxkj4910m.jpg
#   inflating: data/uetjzpw5s3.jpg
#   inflating: data/ug6vqayt49.jpg
#   inflating: data/ugbyf48nv9.jpg
#   inflating: data/ugdlnaf61v.jpg
#   inflating: data/uhdr9pbc68.jpg
#   inflating: data/uhqz65x7ia.jpg
#   inflating: data/uin30jloy8.jpg
#   inflating: data/uiw20z98n5.jpg
#   inflating: data/uiwjd186sa.jpg
#   inflating: data/uj3hz6dtg9.jpg
#   inflating: data/uj4k7dxra3.jpg
#   inflating: data/ujh2qf0lvk.jpg
#   inflating: data/ujnlxyk028.jpg
#   inflating: data/ukjvo7164e.jpg
#   inflating: data/uldh4w7bqr.jpg
#   inflating: data/um1hgs7kd2.jpg
#   inflating: data/umdhk3iab4.jpg
#   inflating: data/umpsk05tzq.jpg
#   inflating: data/uojyhwki0n.jpg
#   inflating: data/up1jt7ioe9.jpg
#   inflating: data/upwylq50zs.jpg
#   inflating: data/uq8ah34ryz.jpg
#   inflating: data/uqyjgihwp4.jpg
#   inflating: data/ur6szkhify.jpg
#   inflating: data/uswt82c3f7.jpg
#   inflating: data/utayink7ez.jpg
#   inflating: data/utg5o0ih6z.jpg
#   inflating: data/utnpwb4oc1.jpg
#   inflating: data/utsd5lnm0y.jpg
#   inflating: data/uwg12c3vdj.jpg
#   inflating: data/uwzjxydi52.jpg
#   inflating: data/ux0c9nb5zi.jpg
#   inflating: data/uxbte9iwol.jpg
#   inflating: data/uxjqrhm8gi.jpg
#   inflating: data/uxp3h518go.jpg
#   inflating: data/uyn307avzf.jpg
#   inflating: data/v0js9w78qt.jpg
#   inflating: data/v0xtd49gr5.jpg
#   inflating: data/v1i6u2hadq.jpg
#   inflating: data/v1wcsaxyu7.jpg
#   inflating: data/v30pbxnfd7.jpg
#   inflating: data/v3e2mxsay1.jpg
#   inflating: data/v49wfjo02y.jpg
#   inflating: data/v6nrahw5xf.jpg
#   inflating: data/v73wolg049.jpg
#   inflating: data/v84esc5hwq.jpg
#   inflating: data/v8r0iotj7s.jpg
#   inflating: data/v907h3oy5m.jpg
#   inflating: data/v9430rfi7h.jpg
#   inflating: data/v9qn60s7ay.jpg
#   inflating: data/va0yifgsce.jpg
#   inflating: data/vagjs43dwb.jpg
#   inflating: data/vapz2d0e6y.jpg
#   inflating: data/vbnm2d41iy.jpg
#   inflating: data/vckolqhrz7.jpg
#   inflating: data/vcrak19nhq.jpg
#   inflating: data/vd1qhaxofc.jpg
#   inflating: data/vde7r4uy8g.jpg
#   inflating: data/vdn1wb8ics.jpg
#   inflating: data/vdsxg6mu2c.jpg
#   inflating: data/vemngh80tc.jpg
#   inflating: data/vfrmch3qp2.jpg
#   inflating: data/vg6mpcyhri.jpg
#   inflating: data/vi7remahxq.jpg
#   inflating: data/vjo6xacp3t.jpg
#   inflating: data/vkpuhdlmey.jpg
#   inflating: data/vksucmbaw8.jpg
#   inflating: data/vkwpygauor.jpg
#   inflating: data/vl1428dwke.jpg
#   inflating: data/vlcxspnq92.jpg
#   inflating: data/vldgo83jq4.jpg
#   inflating: data/vlnqdkwch5.jpg
#   inflating: data/vltg65hypb.jpg
#   inflating: data/vlzs3ih1yg.jpg
#   inflating: data/vmxw570c8t.jpg
#   inflating: data/vne5f9kldo.jpg
#   inflating: data/vnk0aqg3w8.jpg
#   inflating: data/vocu0iw7hm.jpg
#   inflating: data/vojkqzr2i5.jpg
#   inflating: data/vonf9cr8uw.jpg
#   inflating: data/vpk6t0sno2.jpg
#   inflating: data/vpmsgch3en.jpg
#   inflating: data/vpn29j6fq8.jpg
#   inflating: data/vpy6s32ak1.jpg
#   inflating: data/vqhco1fin2.jpg
#   inflating: data/vr5pb3684m.jpg
#   inflating: data/vrgk0sy3bl.jpg
#   inflating: data/vrtw98cbgk.jpg
#   inflating: data/vu1synr2ld.jpg
#   inflating: data/vu2xow7gcj.jpg
#   inflating: data/vu8qck2pyl.jpg
#   inflating: data/vwgaj8x36h.jpg
#   inflating: data/vwuz47enho.jpg
#   inflating: data/vy1ohxusw3.jpg
#   inflating: data/vyd7npghlo.jpg
#   inflating: data/vyreho95ux.jpg
#   inflating: data/vz03waghuq.jpg
#   inflating: data/vz2n0icqt1.jpg
#   inflating: data/vzj09htfuq.jpg
#   inflating: data/vzlirt6auw.jpg
#   inflating: data/w03b5ogfxk.jpg
#   inflating: data/w045gb1xus.jpg
#   inflating: data/w0jr43t62f.jpg
#   inflating: data/w0l5a8zv91.jpg
#   inflating: data/w0p5os9myb.jpg
#   inflating: data/w0zrhsx8a7.jpg
#   inflating: data/w16yn8vi9e.jpg
#   inflating: data/w1kuy2fi6o.jpg
#   inflating: data/w1s09vhkei.jpg
#   inflating: data/w27nmkfge3.jpg
#   inflating: data/w2mx1arjse.jpg
#   inflating: data/w2p476fkb5.jpg
#   inflating: data/w2p6cht3ly.jpg
#   inflating: data/w2v9tap7iz.jpg
#   inflating: data/w4k1yng9tf.jpg
#   inflating: data/w4qhpn839s.jpg
#   inflating: data/w7rxt51abl.jpg
#   inflating: data/w8s69l1hiv.jpg
#   inflating: data/w9cspv37qg.jpg
#   inflating: data/wb14oajt2x.jpg
#   inflating: data/wc6zs3l2dg.jpg
#   inflating: data/wf2gj6947t.jpg
#   inflating: data/wg36obamye.jpg
#   inflating: data/whaqlx8tuz.jpg
#   inflating: data/whmaysji28.jpg
#   inflating: data/widmh6usgb.jpg
#   inflating: data/wkfo51b628.jpg
#   inflating: data/wkin28ve6o.jpg
#   inflating: data/wkq2cxavj0.jpg
#   inflating: data/wkrlf1dx5e.jpg
#   inflating: data/wkt6svud0h.jpg
#   inflating: data/wl37mcoqtu.jpg
#   inflating: data/wmqf94xscb.jpg
#   inflating: data/wnej37o2t6.jpg
#   inflating: data/wo56q7gun2.jpg
#   inflating: data/wpd8temlgf.jpg
#   inflating: data/wq4dhc7plg.jpg
#   inflating: data/wragp32oh6.jpg
#   inflating: data/wrk8zm9vyd.jpg
#   inflating: data/wrqk0si3db.jpg
#   inflating: data/wrsndgyjzf.jpg
#   inflating: data/ws3enarf4x.jpg
#   inflating: data/wsgdbiz3ku.jpg
#   inflating: data/wska7j1lgr.jpg
#   inflating: data/wst0py26hv.jpg
#   inflating: data/wtfb90cihg.jpg
#   inflating: data/wtfimkcv8u.jpg
#   inflating: data/wufv7951st.jpg
#   inflating: data/wvbs9arnp0.jpg
#   inflating: data/wx8no1cjyk.jpg
#   inflating: data/wy1jzlasc4.jpg
#   inflating: data/wy8srcemjf.jpg
#   inflating: data/wys0dev968.jpg
#   inflating: data/wzanx7hd4i.jpg
#   inflating: data/x12ui7p6z0.jpg
#   inflating: data/x1b6pf3hlv.jpg
#   inflating: data/x3cvawts9r.jpg
#   inflating: data/x3ftwo9a1d.jpg
#   inflating: data/x49ako6cbn.jpg
#   inflating: data/x6ijkeatn8.jpg
#   inflating: data/x7bnam04pd.jpg
#   inflating: data/x7fuqrtgv8.jpg
#   inflating: data/x839okpsr2.jpg
#   inflating: data/x96ckwmedv.jpg
#   inflating: data/x986rinb1z.jpg
#   inflating: data/x9oqk4psfi.jpg
#   inflating: data/xa3q9f0nw7.jpg
#   inflating: data/xbrkn7sye0.jpg
#   inflating: data/xc0es58hml.jpg
#   inflating: data/xch35mq6yf.jpg
#   inflating: data/xcu6ijgktv.jpg
#   inflating: data/xcz65ha2sf.jpg
#   inflating: data/xdguayfb4z.jpg
#   inflating: data/xe5f8blhdq.jpg
#   inflating: data/xef56huqj2.jpg
#   inflating: data/xez46twu13.jpg
#   inflating: data/xf6jtcyv5q.jpg
#   inflating: data/xf89pjd62o.jpg
#   inflating: data/xfzau2k4et.jpg
#   inflating: data/xg1h2c307a.jpg
#   inflating: data/xg8lt09fsv.jpg
#   inflating: data/xgtycpzmir.jpg
#   inflating: data/xh8t01rafv.jpg
#   inflating: data/xhegwmkblc.jpg
#   inflating: data/xk6y5ac7mn.jpg
#   inflating: data/xklasoh1m2.jpg
#   inflating: data/xktn8crbf2.jpg
#   inflating: data/xl4vyruk58.jpg
#   inflating: data/xm30zatujk.jpg
#   inflating: data/xmgld3c9ks.jpg
#   inflating: data/xmlwrj5pq1.jpg
#   inflating: data/xos98jewhc.jpg
#   inflating: data/xouyq5lr63.jpg
#   inflating: data/xp07krsqvu.jpg
#   inflating: data/xpcte0n3qm.jpg
#   inflating: data/xpuidown25.jpg
#   inflating: data/xpwsfu178t.jpg
#   inflating: data/xq3klre8yn.jpg
#   inflating: data/xq3o5lndtr.jpg
#   inflating: data/xqp0dwo92t.jpg
#   inflating: data/xrc93jsy6g.jpg
#   inflating: data/xs71ci35m6.jpg
#   inflating: data/xstdcqruzm.jpg
#   inflating: data/xsw9qv0oy5.jpg
#   inflating: data/xtsrvfcw5e.jpg
#   inflating: data/xu18p0nm7z.jpg
#   inflating: data/xuphae4cgf.jpg
#   inflating: data/xvu7ysbajn.jpg
#   inflating: data/xyqj6vubkn.jpg
#   inflating: data/xzeqtv67p3.jpg
#   inflating: data/xzuk9ijngd.jpg
#   inflating: data/y04pfgq65m.jpg
#   inflating: data/y058cohfkg.jpg
#   inflating: data/y0u1iwft7r.jpg
#   inflating: data/y1ec6d48az.jpg
#   inflating: data/y1ihq6ufs8.jpg
#   inflating: data/y1p5g8hsq6.jpg
#   inflating: data/y214qicd3x.jpg
#   inflating: data/y31pqcahlu.jpg
#   inflating: data/y3scgxkje4.jpg
#   inflating: data/y5qbdhfu07.jpg
#   inflating: data/y72lj3tbc5.jpg
#   inflating: data/y7hvrlko0e.jpg
#   inflating: data/y7jmql0obx.jpg
#   inflating: data/y7kmwceang.jpg
#   inflating: data/y7m8ebhko9.jpg
#   inflating: data/y7n9rut2sc.jpg
#   inflating: data/y81b3dms5n.jpg
#   inflating: data/y86keuj5ox.jpg
#   inflating: data/y8cq54wgm0.jpg
#   inflating: data/y8pf1lgvnc.jpg
#   inflating: data/ycf9onuvgj.jpg
#   inflating: data/ydb9vfk8oe.jpg
#   inflating: data/yfj4ov675x.jpg
#   inflating: data/yg38c6ph05.jpg
#   inflating: data/yg6z4fxb8d.jpg
#   inflating: data/yg90zn2vpl.jpg
#   inflating: data/yghzv9t4b6.jpg
#   inflating: data/ygikt8alvc.jpg
#   inflating: data/yhpse475u0.jpg
#   inflating: data/yjark5bls2.jpg
#   inflating: data/yl2mo8edt1.jpg
#   inflating: data/ylacr28jqn.jpg
#   inflating: data/ym2kqgnl90.jpg
#   inflating: data/ym97fnuxpk.jpg
#   inflating: data/yoma90vldf.jpg
#   inflating: data/ypum98e5ws.jpg
#   inflating: data/yr0fvd4j6b.jpg
#   inflating: data/yr2iokuv98.jpg
#   inflating: data/yrqh5dvngz.jpg
#   inflating: data/yrucdahpm5.jpg
#   inflating: data/yscl65wze4.jpg
#   inflating: data/yt6ha5dsop.jpg
#   inflating: data/ytosm8ecwa.jpg
#   inflating: data/yv185rj7gw.jpg
#   inflating: data/yvju081gd6.jpg
#   inflating: data/ywet5k4csu.jpg
#   inflating: data/yx16p50lhw.jpg
#   inflating: data/yx8n5fvcbz.jpg
#   inflating: data/z0rqdi78tv.jpg
#   inflating: data/z1inxcdtpv.jpg
#   inflating: data/z29e6d5tai.jpg
#   inflating: data/z394wdmu0n.jpg
#   inflating: data/z3g7wb0pah.jpg
#   inflating: data/z521b46897.jpg
#   inflating: data/z6hurl15nd.jpg
#   inflating: data/z6thvaegw1.jpg
#   inflating: data/z9ore680uf.jpg
#   inflating: data/zacbk1e23q.jpg
#   inflating: data/zax6ufy9tb.jpg
#   inflating: data/zbehxidyv0.jpg
#   inflating: data/zbnmre40c5.jpg
#   inflating: data/zcjqhoyiun.jpg
#   inflating: data/zdse9yhx2f.jpg
#   inflating: data/zdy20axn9i.jpg
#   inflating: data/ze0vndq7ia.jpg
#   inflating: data/ze5vlg1f0u.jpg
#   inflating: data/zegmjw1a4t.jpg
#   inflating: data/zeyjtp6uwn.jpg
#   inflating: data/zf9yqcuhxa.jpg
#   inflating: data/zft9e6qnu0.jpg
#   inflating: data/zgc2mnh7u1.jpg
#   inflating: data/zgclfw96kh.jpg
#   inflating: data/zgqm6jlpiu.jpg
#   inflating: data/zgy2obdwaj.jpg
#   inflating: data/zh69avu24k.jpg
#   inflating: data/zhb425a9ce.jpg
#   inflating: data/zhdp3y8mq0.jpg
#   inflating: data/zhelcfsn9y.jpg
#   inflating: data/zhf3bpm5ne.jpg
#   inflating: data/zhg3nvpq5b.jpg
#   inflating: data/zhwtxjn53c.jpg
#   inflating: data/zi1nx5rjwb.jpg
#   inflating: data/zi684vlmpg.jpg
#   inflating: data/zia9kyuohd.jpg
#   inflating: data/zjf9rqgxu0.jpg
#   inflating: data/zjqclouebx.jpg
#   inflating: data/zkj614brlh.jpg
#   inflating: data/zlpef0vcos.jpg
#   inflating: data/zluvr8ojiw.jpg
#   inflating: data/zmhtnic29s.jpg
#   inflating: data/zmlvxb7ki0.jpg
#   inflating: data/zn8jshfrp6.jpg
#   inflating: data/zna1vob5ke.jpg
#   inflating: data/zp7nm6yjd9.jpg
#   inflating: data/zpv0blo4q6.jpg
#   inflating: data/zpviw32thd.jpg
#   inflating: data/zq09k7cio5.jpg
#   inflating: data/zqrl6bjp28.jpg
#   inflating: data/zrg1i5j2vt.jpg
#   inflating: data/zst40rh35g.jpg
#   inflating: data/ztbxuh3c05.jpg
#   inflating: data/ztm78n2l6g.jpg
#   inflating: data/ztw5agxrlk.jpg
#   inflating: data/zv310diysc.jpg
#   inflating: data/zvltb5j4e2.jpg
#   inflating: data/zwh3lyv75s.jpg
#   inflating: data/zwmby0rk5g.jpg
#   inflating: data/zwnc62gvtp.jpg
#   inflating: data/zxa49ovwe3.jpg
#   inflating: data/zxl7y9shwv.jpg
#   inflating: data/zy9m06bhgl.jpg
#   inflating: data/zycmxdas26.jpg
#   inflating: data/zyebproc9x.jpg
#   inflating: data/label.csv

# %%
# 將訓練資料分成 train/test
# 其中 test size 設為 0.2

from pathlib import Path
import pandas as pd
import cv2
from tqdm.notebook import tqdm
from sklearn.model_selection import train_test_split

def split_dataset(img_dir: str = "data",
                  csv_dir: str = "label.csv", 
                  save_dir: str = "orchid_dataset", 
                  test_size: float = 0.2,
                  random_state: int = None
                  ) -> None:

    # 建立 train/test 資料夾
    Path.mkdir(Path(save_dir))
    Path.mkdir(Path(save_dir) / "train")
    Path.mkdir(Path(save_dir) / "test")

    # 將資料分成 orchid_dataset/train 和 orchid_dataset/test
    df = pd.read_csv(Path(img_dir) / csv_dir)
    train, test = train_test_split(
        df, test_size=test_size, stratify=df["category"], shuffle=True, random_state=random_state
    )
    train_save_path = Path(save_dir) / "train"
    test_save_path = Path(save_dir) / "test"

    for df_, save_dir_ in zip([train, test], [train_save_path, test_save_path]):
        label_list = df_["category"].unique()

        for label in tqdm(label_list):
            label_dir = Path(save_dir_) / str(label)
            if not Path.exists(label_dir):
                Path.mkdir(label_dir)

            sub_df = df_[df_["category"] == label]
            for f in sub_df["filename"]:
                img_path = str(Path(img_dir) / f)
                save_dir = str(Path(save_dir_) / str(label) / f)
                img = cv2.imread(img_path)
                cv2.imwrite(save_dir, img)

    train.to_csv(str(train_save_path) + ".csv", index=False)
    test.to_csv(str(test_save_path) + ".csv", index=False)

# 使用固定的random_state是為了在固定樣本之下去改進模型
# 也可以用random seed，但由於test的樣本數很少，隨機性影響很大
random_state = None
test_size = 0.2
split_dataset(test_size=test_size, random_state=random_state)
# Out:
#   0%|          | 0/219 [00:00<?, ?it/s]
#   0%|          | 0/219 [00:00<?, ?it/s]

# %% [markdown]
# # 資料處理 (Data Augmentation)

# %% [markdown]
# 本次競賽中

# %%
"""
3Augment implementation
Data-augmentation (DA) based on dino DA (https://github.com/facebookresearch/dino)
and timm DA(https://github.com/rwightman/pytorch-image-models)
"""

# Copyright (c) Meta Platforms, Inc. and affiliates.
# All rights reserved.

import random
from torchvision import transforms
from PIL import ImageFilter, ImageOps

class Solarization(object):
    """
    Apply Solarization to the PIL image.
    """

    def __init__(self, p=0.2):
        self.p = p

    def __call__(self, img):
        if random.random() < self.p:
            return ImageOps.solarize(img)
        else:
            return img


class GaussianBlur(object):
    """
    Apply Gaussian Blur to the PIL image.
    """

    def __init__(self, p=0.1, radius_min=0.1, radius_max=2.0):
        self.prob = p
        self.radius_min = radius_min
        self.radius_max = radius_max

    def __call__(self, img):
        do_it = random.random() <= self.prob
        if not do_it:
            return img

        img = img.filter(
            ImageFilter.GaussianBlur(
                radius=random.uniform(self.radius_min, self.radius_max)
            )
        )
        return img


class gray_scale(object):
    """
    Apply Solarization to the PIL image.
    """

    def __init__(self, p=0.2):
        self.p = p
        self.transf = transforms.Grayscale(3)

    def __call__(self, img):
        if random.random() < self.p:
            return self.transf(img)
        else:
            return img

# %% [markdown]
# # Help Function

# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from sklearn.metrics import accuracy_score, f1_score

@torch.no_grad()
def evaluate(model: nn.Module, dataloader: DataLoader, device: str):

    model.eval()
    criterion = nn.CrossEntropyLoss()

    total_loss, total_acc = 0, 0
    outputs, labels = [], []

    for _, (data, label) in enumerate(dataloader):
        data, label = data.to(device), label.to(device)
        output = model(data)
        loss = criterion(output, label)
        y_true = label.cpu().numpy()
        y_pred = torch.argmax(output, 1).cpu().numpy()
        acc = accuracy_score(y_true, y_pred)
        total_loss += loss
        total_acc += acc
        outputs.append(y_pred)
        labels.append(y_true)

    avg_loss = total_loss / len(dataloader)
    avg_acc = total_acc / len(dataloader)

    outputs = np.concatenate(outputs)
    labels = np.concatenate(labels)
    macro_f1 = f1_score(outputs, labels, average="macro")

    final_score = 0.5 * (avg_acc + macro_f1)

    return avg_loss, avg_acc, macro_f1, final_score

# %% [markdown]
# # 訓練模型

# %% [markdown]
# ## Swin-v2 192

# %%
import time
from torchvision.datasets import ImageFolder 
from torch.utils.data import DataLoader
from torchvision import transforms as T
import timm
from timm.loss import LabelSmoothingCrossEntropy
from timm.scheduler import CosineLRScheduler
from timm.utils.clip_grad import dispatch_clip_grad
from timm.models.swin_transformer_v2 import swinv2_base_window12_192_22k

# data preprocessing configuration
TRAIN_DIR = "/content/orchid_dataset/train"
TEST_DIR = "/content/orchid_dataset/test"
IMAGE_SIZE = 192
TEST_RESIZE = int((256 / 224) * IMAGE_SIZE)

# training configuration
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
EPOCHS = 200
BATCH_SIZE = 32
MODEL_NAME = "swinv2_base_window12_192_22k"

# optimizer configuration
LEARNING_RATE = 3e-3

# lr scheduler configuration
T_INITIAL = 10
WARMUP_T = 5
WARMUP_LR_INIT = 1e-5
K_DECAY = 0.75
LR_MIN = 1e-5

# data augmentation
three_augment = T.Compose(
    [T.RandomChoice([gray_scale(p=0.5), Solarization(p=0.5), GaussianBlur(p=0.5)])]
)
color_jitter = 0.2
normalize = T.Normalize(mean=[0.4909, 0.4216, 0.3703], std=[0.2459, 0.2420, 0.2489])
transform = {
    "train": T.Compose(
        [
            T.Resize(IMAGE_SIZE, interpolation=T.InterpolationMode.BICUBIC),
            T.RandomCrop(IMAGE_SIZE, padding=4, padding_mode="reflect"),
            T.RandomHorizontalFlip(),
            three_augment,
            T.ColorJitter(color_jitter, color_jitter, color_jitter),
            T.ToTensor(),
            normalize,
        ]
    ),
    "val": T.Compose(
        [
            T.Resize(IMAGE_SIZE, interpolation=T.InterpolationMode.BICUBIC),
            T.CenterCrop(IMAGE_SIZE),
            T.ToTensor(),
            normalize,
        ]
    ),
}



def main():

    train_dataset = ImageFolder(root=TRAIN_DIR, transform=transform["train"])
    val_dataset = ImageFolder(root=TEST_DIR, transform=transform["val"])
    train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=True)

    num_classes = len(train_dataset.classes)
    model = swinv2_base_window12_192_22k(
        pretrained=True, 
        num_classes=num_classes, 
        drop_rate=0.1, 
        attn_drop_rate=0.1, 
        drop_path_rate=0.1)
    
    # only train MSA(multi-head self-attention) and head
    for name_p, p in model.named_parameters():
        if ".attn." in name_p:
            p.requires_grad = True
        else:
            p.requires_grad = False
    
    model.head.weight.requires_grad = True
    model.head.bias.requires_grad = True
    
    try:
        for p in model.patch_embed.parameters():
                p.requires_grad = False
    except:
        print('no patch embed')

    print(
        f"number of params: {sum(p.numel() for p in model.parameters() if p.requires_grad)}"
    )

    model.to(DEVICE)

    criterion = LabelSmoothingCrossEntropy(0.1)
    optimizer = torch.optim.AdamW(model.parameters(), lr=LEARNING_RATE, weight_decay=0.02)
    scheduler = CosineLRScheduler(
        optimizer,
        t_initial=T_INITIAL,
        warmup_t=WARMUP_T,
        warmup_lr_init=WARMUP_LR_INIT,
        k_decay=K_DECAY,
        lr_min=LR_MIN,
    )

    for epoch in range(EPOCHS):
        start_time = time.time()
        for i, (data, label) in tqdm(enumerate(train_loader), total=len(train_loader)):
            model.train()
            # forward pass
            data, label = data.to(DEVICE), label.to(DEVICE)
            output = model(data)
            loss = criterion(output, label)

            # backward pass
            optimizer.zero_grad()
            loss.backward()

            # clip gradient
            dispatch_clip_grad(model.parameters(), 5.0)

            # gradient decent or adam step
            optimizer.step()

        
        # update scheduler
        scheduler.step_update(epoch)

        if (epoch+1) % 2 == 0:
            
            # Print current metric
            train_loss, train_acc, train_macro_f1, train_final_scroe = evaluate(model, train_loader, DEVICE)
            val_loss, val_acc, val_macro_f1, val_final_scroe= evaluate(model, val_loader, DEVICE)

            print(
                f"【Epoch={epoch+1}】 train:【loss={train_loss:.3f}, acc={100*train_acc:.2f}%, f1={train_final_scroe:.3f}, final={train_final_scroe:.3f}】 \
                val: 【loss={val_loss:.3f}, acc={100*val_acc:.2f}%, f1={val_macro_f1:.3f}, final={val_final_scroe:.3f}】 {(time.time() - start_time):.2f}/s"
            )

            torch.save(
                {
                    "epoch": epoch,
                    "model": model.state_dict(),
                    "optimizer": optimizer.state_dict(),
                    "scheduler": scheduler.state_dict(),
                },
                f=f"{MODEL_NAME}.pt",
            )

            

if __name__ == "__main__":
    main()
# Out:
# number of params: 28408659
#   0%|          | 0/55 [00:00<?, ?it/s]
#   0%|          | 0/55 [00:00<?, ?it/s]
# 【Epoch=2】 train:【loss=5.196, acc=2.50%, f1=0.021, final=0.021】                 val: 【loss=5.170, acc=2.66%, f1=0.016, final=0.021】 86.22/s
#   0%|          | 0/55 [00:00<?, ?it/s]
#   0%|          | 0/55 [00:00<?, ?it/s]
# 【Epoch=4】 train:【loss=4.470, acc=12.18%, f1=0.108, final=0.108】                 val: 【loss=4.470, acc=12.80%, f1=0.089, final=0.108】 87.68/s
#   0%|          | 0/55 [00:00<?, ?it/s]
#   0%|          | 0/55 [00:00<?, ?it/s]
# 【Epoch=6】 train:【loss=3.452, acc=28.92%, f1=0.270, final=0.270】                 val: 【loss=3.508, acc=28.41%, f1=0.231, final=0.257】 87.92/s
#   0%|          | 0/55 [00:00<?, ?it/s]
#   0%|          | 0/55 [00:00<?, ?it/s]
# 【Epoch=8】 train:【loss=2.538, acc=48.24%, f1=0.472, final=0.472】                 val: 【loss=2.688, acc=39.96%, f1=0.349, final=0.374】 86.57/s
#   0%|          | 0/55 [00:00<?, ?it/s]
#   0%|          | 0/55 [00:00<?, ?it/s]
# 【Epoch=10】 train:【loss=1.900, acc=62.56%, f1=0.617, final=0.617】                 val: 【loss=2.089, acc=54.53%, f1=0.491, final=0.518】 90.09/s
#   0%|          | 0/55 [00:00<?, ?it/s]
#   0%|          | 0/55 [00:00<?, ?it/s]
# 【Epoch=12】 train:【loss=1.450, acc=71.95%, f1=0.714, final=0.714】                 val: 【loss=1.693, acc=62.80%, f1=0.581, final=0.604】 87.67/s
#   0%|          | 0/55 [00:00<?, ?it/s]
#   0%|          | 0/55 [00:00<?, ?it/s]
# 【Epoch=14】 train:【loss=1.092, acc=79.64%, f1=0.793, final=0.793】                 val: 【loss=1.366, acc=67.67%, f1=0.638, final=0.657】 86.58/s
#   0%|          | 0/55 [00:00<?, ?it/s]
#   0%|          | 0/55 [00:00<?, ?it/s]
# 【Epoch=16】 train:【loss=0.908, acc=82.86%, f1=0.827, final=0.827】                 val: 【loss=1.189, acc=73.92%, f1=0.707, final=0.723】 86.44/s
#   0%|          | 0/55 [00:00<?, ?it/s]
#   0%|          | 0/55 [00:00<?, ?it/s]
# 【Epoch=18】 train:【loss=0.773, acc=85.95%, f1=0.859, final=0.859】                 val: 【loss=1.072, acc=76.06%, f1=0.735, final=0.748】 86.62/s
#   0%|          | 0/55 [00:00<?, ?it/s]
#   0%|          | 0/55 [00:00<?, ?it/s]
# 【Epoch=20】 train:【loss=0.633, acc=90.08%, f1=0.899, final=0.899】                 val: 【loss=0.964, acc=79.30%, f1=0.771, final=0.782】 87.05/s
#   0%|          | 0/55 [00:00<?, ?it/s]
#   0%|          | 0/55 [00:00<?, ?it/s]
# 【Epoch=22】 train:【loss=0.608, acc=90.17%, f1=0.901, final=0.901】                 val: 【loss=0.965, acc=78.08%, f1=0.761, final=0.771】 86.41/s
#   0%|          | 0/55 [00:00<?, ?it/s]
#   0%|          | 0/55 [00:00<?, ?it/s]
# 【Epoch=24】 train:【loss=0.555, acc=92.50%, f1=0.925, final=0.925】                 val: 【loss=0.932, acc=79.85%, f1=0.779, final=0.789】 87.18/s
#   0%|          | 0/55 [00:00<?, ?it/s]
#   0%|          | 0/55 [00:00<?, ?it/s]
# 【Epoch=26】 train:【loss=0.445, acc=93.71%, f1=0.936, final=0.936】                 val: 【loss=0.836, acc=82.16%, f1=0.798, final=0.810】 86.24/s
#   0%|          | 0/55 [00:00<?, ?it/s]
#   0%|          | 0/55 [00:00<?, ?it/s]
# 【Epoch=28】 train:【loss=0.448, acc=93.54%, f1=0.935, final=0.935】                 val: 【loss=0.845, acc=83.06%, f1=0.809, final=0.820】 86.26/s
#   0%|          | 0/55 [00:00<?, ?it/s]
#   0%|          | 0/55 [00:00<?, ?it/s]
# 【Epoch=30】 train:【loss=0.410, acc=95.13%, f1=0.952, final=0.952】                 val: 【loss=0.836, acc=83.20%, f1=0.812, final=0.822】 86.30/s
#   0%|          | 0/55 [00:00<?, ?it/s]
#   0%|          | 0/55 [00:00<?, ?it/s]
# 【Epoch=32】 train:【loss=0.376, acc=96.52%, f1=0.965, final=0.965】                 val: 【loss=0.812, acc=84.98%, f1=0.835, final=0.843】 86.29/s
#   0%|          | 0/55 [00:00<?, ?it/s]
#   0%|          | 0/55 [00:00<?, ?it/s]
# 【Epoch=34】 train:【loss=0.342, acc=96.93%, f1=0.969, final=0.969】                 val: 【loss=0.796, acc=84.54%, f1=0.832, final=0.839】 86.80/s
#   0%|          | 0/55 [00:00<?, ?it/s]
#   0%|          | 0/55 [00:00<?, ?it/s]
# 【Epoch=36】 train:【loss=0.314, acc=97.42%, f1=0.974, final=0.974】                 val: 【loss=0.788, acc=85.09%, f1=0.836, final=0.843】 86.26/s
#   0%|          | 0/55 [00:00<?, ?it/s]
#   0%|          | 0/55 [00:00<?, ?it/s]
# 【Epoch=38】 train:【loss=0.279, acc=98.07%, f1=0.981, final=0.981】                 val: 【loss=0.757, acc=87.54%, f1=0.863, final=0.869】 87.10/s
#   0%|          | 0/55 [00:00<?, ?it/s]
#   0%|          | 0/55 [00:00<?, ?it/s]
# 【Epoch=40】 train:【loss=0.243, acc=98.92%, f1=0.989, final=0.989】                 val: 【loss=0.712, acc=88.96%, f1=0.878, final=0.884】 86.34/s
#   0%|          | 0/55 [00:00<?, ?it/s]
#   0%|          | 0/55 [00:00<?, ?it/s]
# 【Epoch=42】 train:【loss=0.251, acc=98.45%, f1=0.984, final=0.984】                 val: 【loss=0.745, acc=86.75%, f1=0.856, final=0.862】 87.16/s
#   0%|          | 0/55 [00:00<?, ?it/s]
#   0%|          | 0/55 [00:00<?, ?it/s]
# 【Epoch=44】 train:【loss=0.217, acc=98.75%, f1=0.987, final=0.987】                 val: 【loss=0.702, acc=88.66%, f1=0.878, final=0.882】 86.28/s
#   0%|          | 0/55 [00:00<?, ?it/s]
#   0%|          | 0/55 [00:00<?, ?it/s]
# 【Epoch=46】 train:【loss=0.238, acc=98.28%, f1=0.983, final=0.983】                 val: 【loss=0.753, acc=87.54%, f1=0.866, final=0.871】 86.38/s
#   0%|          | 0/55 [00:00<?, ?it/s]
#   0%|          | 0/55 [00:00<?, ?it/s]
# 【Epoch=48】 train:【loss=0.205, acc=98.64%, f1=0.986, final=0.986】                 val: 【loss=0.700, acc=88.43%, f1=0.879, final=0.881】 86.58/s
#   0%|          | 0/55 [00:00<?, ?it/s]
#   0%|          | 0/55 [00:00<?, ?it/s]
# 【Epoch=50】 train:【loss=0.203, acc=98.67%, f1=0.987, final=0.987】                 val: 【loss=0.689, acc=90.20%, f1=0.892, final=0.897】 86.50/s
#   0%|          | 0/55 [00:00<?, ?it/s]
#   0%|          | 0/55 [00:00<?, ?it/s]
# 【Epoch=52】 train:【loss=0.184, acc=98.98%, f1=0.989, final=0.989】                 val: 【loss=0.672, acc=90.30%, f1=0.893, final=0.898】 86.45/s
#   0%|          | 0/55 [00:00<?, ?it/s]
#   0%|          | 0/55 [00:00<?, ?it/s]
# 【Epoch=54】 train:【loss=0.168, acc=99.22%, f1=0.992, final=0.992】                 val: 【loss=0.679, acc=89.43%, f1=0.885, final=0.890】 86.35/s
#   0%|          | 0/55 [00:00<?, ?it/s]
#   0%|          | 0/55 [00:00<?, ?it/s]
# 【Epoch=56】 train:【loss=0.175, acc=99.32%, f1=0.993, final=0.993】                 val: 【loss=0.675, acc=90.85%, f1=0.900, final=0.904】 86.39/s
#   0%|          | 0/55 [00:00<?, ?it/s]
#   0%|          | 0/55 [00:00<?, ?it/s]
# 【Epoch=58】 train:【loss=0.162, acc=99.41%, f1=0.994, final=0.994】                 val: 【loss=0.664, acc=89.65%, f1=0.887, final=0.892】 86.38/s
#   0%|          | 0/55 [00:00<?, ?it/s]
#   0%|          | 0/55 [00:00<?, ?it/s]
# 【Epoch=60】 train:【loss=0.170, acc=99.09%, f1=0.991, final=0.991】                 val: 【loss=0.673, acc=89.65%, f1=0.889, final=0.893】 87.10/s
#   0%|          | 0/55 [00:00<?, ?it/s]
#   0%|          | 0/55 [00:00<?, ?it/s]
# 【Epoch=62】 train:【loss=0.168, acc=99.49%, f1=0.995, final=0.995】                 val: 【loss=0.692, acc=89.98%, f1=0.889, final=0.895】 86.27/s
#   0%|          | 0/55 [00:00<?, ?it/s]
#   0%|          | 0/55 [00:00<?, ?it/s]
# 【Epoch=64】 train:【loss=0.158, acc=99.47%, f1=0.995, final=0.995】                 val: 【loss=0.686, acc=90.56%, f1=0.902, final=0.904】 86.96/s
#   0%|          | 0/55 [00:00<?, ?it/s]
#   0%|          | 0/55 [00:00<?, ?it/s]
# 【Epoch=66】 train:【loss=0.148, acc=99.43%, f1=0.994, final=0.994】                 val: 【loss=0.654, acc=91.31%, f1=0.902, final=0.908】 86.24/s
#   0%|          | 0/55 [00:00<?, ?it/s]
#   0%|          | 0/55 [00:00<?, ?it/s]
# 【Epoch=68】 train:【loss=0.135, acc=99.94%, f1=0.999, final=0.999】                 val: 【loss=0.644, acc=90.77%, f1=0.903, final=0.906】 87.03/s
#   0%|          | 0/55 [00:00<?, ?it/s]
#   0%|          | 0/55 [00:00<?, ?it/s]
# 【Epoch=70】 train:【loss=0.156, acc=99.60%, f1=0.996, final=0.996】                 val: 【loss=0.670, acc=91.64%, f1=0.909, final=0.913】 86.18/s
#   0%|          | 0/55 [00:00<?, ?it/s]
#   0%|          | 0/55 [00:00<?, ?it/s]
# 【Epoch=72】 train:【loss=0.147, acc=99.77%, f1=0.998, final=0.998】                 val: 【loss=0.662, acc=91.07%, f1=0.901, final=0.906】 86.33/s
#   0%|          | 0/55 [00:00<?, ?it/s]
#   0%|          | 0/55 [00:00<?, ?it/s]
# 【Epoch=74】 train:【loss=0.138, acc=99.77%, f1=0.998, final=0.998】                 val: 【loss=0.657, acc=90.65%, f1=0.897, final=0.902】 86.44/s
#   0%|          | 0/55 [00:00<?, ?it/s]
#   0%|          | 0/55 [00:00<?, ?it/s]
# 【Epoch=76】 train:【loss=0.146, acc=99.66%, f1=0.997, final=0.997】                 val: 【loss=0.676, acc=92.19%, f1=0.916, final=0.919】 86.31/s
#   0%|          | 0/55 [00:00<?, ?it/s]
#   0%|          | 0/55 [00:00<?, ?it/s]
# 【Epoch=78】 train:【loss=0.130, acc=99.83%, f1=0.998, final=0.998】                 val: 【loss=0.648, acc=90.85%, f1=0.898, final=0.903】 86.34/s
#   0%|          | 0/55 [00:00<?, ?it/s]
#   0%|          | 0/55 [00:00<?, ?it/s]
# 【Epoch=80】 train:【loss=0.139, acc=99.83%, f1=0.998, final=0.998】                 val: 【loss=0.679, acc=90.77%, f1=0.902, final=0.905】 86.12/s
#   0%|          | 0/55 [00:00<?, ?it/s]
#   0%|          | 0/55 [00:00<?, ?it/s]
# 【Epoch=82】 train:【loss=0.135, acc=99.77%, f1=0.998, final=0.998】                 val: 【loss=0.663, acc=91.19%, f1=0.905, final=0.908】 85.98/s
#   0%|          | 0/55 [00:00<?, ?it/s]
#   0%|          | 0/55 [00:00<?, ?it/s]
# 【Epoch=84】 train:【loss=0.128, acc=99.70%, f1=0.997, final=0.997】                 val: 【loss=0.649, acc=91.42%, f1=0.909, final=0.912】 85.95/s
#   0%|          | 0/55 [00:00<?, ?it/s]
#   0%|          | 0/55 [00:00<?, ?it/s]
# 【Epoch=86】 train:【loss=0.132, acc=99.72%, f1=0.997, final=0.997】                 val: 【loss=0.669, acc=90.44%, f1=0.898, final=0.901】 85.98/s
#   0%|          | 0/55 [00:00<?, ?it/s]
#   0%|          | 0/55 [00:00<?, ?it/s]
# 【Epoch=88】 train:【loss=0.123, acc=99.77%, f1=0.998, final=0.998】                 val: 【loss=0.639, acc=91.64%, f1=0.910, final=0.913】 85.96/s
#   0%|          | 0/55 [00:00<?, ?it/s]
#   0%|          | 0/55 [00:00<?, ?it/s]
# 【Epoch=90】 train:【loss=0.138, acc=99.89%, f1=0.999, final=0.999】                 val: 【loss=0.690, acc=90.10%, f1=0.897, final=0.899】 86.99/s
#   0%|          | 0/55 [00:00<?, ?it/s]
#   0%|          | 0/55 [00:00<?, ?it/s]
# 【Epoch=92】 train:【loss=0.126, acc=99.83%, f1=0.998, final=0.998】                 val: 【loss=0.665, acc=91.11%, f1=0.908, final=0.910】 86.57/s
#   0%|          | 0/55 [00:00<?, ?it/s]
#   0%|          | 0/55 [00:00<?, ?it/s]
# 【Epoch=94】 train:【loss=0.131, acc=99.72%, f1=0.997, final=0.997】                 val: 【loss=0.661, acc=91.31%, f1=0.910, final=0.911】 86.75/s
#   0%|          | 0/55 [00:00<?, ?it/s]
#   0%|          | 0/55 [00:00<?, ?it/s]
# 【Epoch=96】 train:【loss=0.135, acc=99.77%, f1=0.998, final=0.998】                 val: 【loss=0.675, acc=90.52%, f1=0.898, final=0.902】 86.05/s
#   0%|          | 0/55 [00:00<?, ?it/s]
#   0%|          | 0/55 [00:00<?, ?it/s]
# 【Epoch=98】 train:【loss=0.126, acc=99.72%, f1=0.997, final=0.997】                 val: 【loss=0.661, acc=91.21%, f1=0.908, final=0.910】 86.84/s
#   0%|          | 0/55 [00:00<?, ?it/s]
#   0%|          | 0/55 [00:00<?, ?it/s]
# 【Epoch=100】 train:【loss=0.130, acc=99.89%, f1=0.999, final=0.999】                 val: 【loss=0.684, acc=90.52%, f1=0.897, final=0.901】 86.21/s
#   0%|          | 0/55 [00:00<?, ?it/s]
#   0%|          | 0/55 [00:00<?, ?it/s]
# 【Epoch=102】 train:【loss=0.120, acc=99.77%, f1=0.998, final=0.998】                 val: 【loss=0.649, acc=91.07%, f1=0.904, final=0.907】 86.92/s
#   0%|          | 0/55 [00:00<?, ?it/s]
#   0%|          | 0/55 [00:00<?, ?it/s]
# 【Epoch=104】 train:【loss=0.120, acc=99.89%, f1=0.999, final=0.999】                 val: 【loss=0.653, acc=90.87%, f1=0.903, final=0.906】 86.09/s
#   0%|          | 0/55 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-bc90418c586f> in <module>()
#     156
#     157 if __name__ == "__main__":
# --> 158     main()
#
# <ipython-input-11-bc90418c586f> in main()
#     120             # backward pass
#     121             optimizer.zero_grad()
# --> 122             loss.backward()
#     123
#     124             # clip gradient
#
# /usr/local/lib/python3.7/dist-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     361                 create_graph=create_graph,
#     362                 inputs=inputs)
# --> 363         torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#     364
#     365     def register_hook(self, hook):
#
# /usr/local/lib/python3.7/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     173     Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     174         tensors, grad_tensors_, retain_graph, create_graph, inputs,
# --> 175         allow_unreachable=True, accumulate_grad=True)  # Calls into the C++ engine to run the backward pass
#     176
#     177 def grad(
#
# KeyboardInterrupt:

# %% [markdown]
# ## Swin-v2 384

# %%
import time
from torchvision.datasets import ImageFolder 
from torch.utils.data import DataLoader
from torchvision import transforms as T
import timm
from timm.loss import LabelSmoothingCrossEntropy
from timm.scheduler import CosineLRScheduler
from timm.utils.clip_grad import dispatch_clip_grad
from timm.models.swin_transformer_v2 import swinv2_base_window12to24_192to384_22kft1k

# data preprocessing configuration
TRAIN_DIR = "/content/orchid_dataset/train"
TEST_DIR = "/content/orchid_dataset/test"
IMAGE_SIZE = 384
TEST_RESIZE = int((256 / 224) * IMAGE_SIZE)

# training
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
EPOCHS = 100
BATCH_SIZE = 2

MODEL_NAME = "swinv2_base_window12to24_192to384_22kft1k"

# optimizer
LEARNING_RATE = 2e-3

# lr scheduler
T_INITIAL = 10
WARMUP_T = 5
WARMUP_LR_INIT = 1e-5
K_DECAY = 0.75
LR_MIN = 1e-5

# data augmentation
normalize = T.Normalize(mean=[0.4909, 0.4216, 0.3703], std=[0.2459, 0.2420, 0.2489])
transform = {
    "train": T.Compose(
        [
            T.Resize(IMAGE_SIZE, interpolation=T.InterpolationMode.BICUBIC),
            T.CenterCrop(IMAGE_SIZE),
            T.ToTensor(),
            normalize,
        ]
    ),
    "val": T.Compose(
        [
            T.Resize(IMAGE_SIZE, interpolation=T.InterpolationMode.BICUBIC),
            T.CenterCrop(IMAGE_SIZE),
            T.ToTensor(),
            normalize,
        ]
    ),
}



def main():

    train_dataset = ImageFolder(root=TRAIN_DIR, transform=transform["train"])
    val_dataset = ImageFolder(root=TEST_DIR, transform=transform["val"])
    train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=True)

    num_classes = len(train_dataset.classes)
    model = swinv2_base_window12to24_192to384_22kft1k( 
                              pretrained=False, 
                              num_classes=num_classes,
                              img_size=IMAGE_SIZE,
                              drop_rate=0.1, 
                              attn_drop_rate=0.1, 
                              drop_path_rate=0.1)
    
    state_dict = model.state_dict()
    checkpoint = torch.load("swinv2_base_window12_192_22k.pt", map_location='cpu')
    checkpoint_model = checkpoint['model']

    pre_trained_layers = {}
    for k, v in checkpoint_model.items():
        if checkpoint_model[k].shape == state_dict[k].shape:
            pre_trained_layers[k] = v 

    model.load_state_dict(pre_trained_layers, strict=False)

    for name_p, p in model.named_parameters():
        if ".attn." in name_p:
            p.requires_grad = True
        else:
            p.requires_grad = False
    
    model.head.weight.requires_grad = True
    model.head.bias.requires_grad = True

    try:
        model.pos_embed.requires_grad = True
    except:
        print('no position encoding')
    
    try:
        for p in model.patch_embed.parameters():
                p.requires_grad = False
    except:
        print('no patch embed')

    print(
        f"number of params: {sum(p.numel() for p in model.parameters() if p.requires_grad)}"
    )

    model.to(DEVICE)

    criterion = LabelSmoothingCrossEntropy(0.1)
    optimizer = torch.optim.AdamW(model.parameters(), lr=LEARNING_RATE, weight_decay=0.05)
    scheduler = CosineLRScheduler(
        optimizer,
        t_initial=T_INITIAL,
        warmup_t=WARMUP_T,
        warmup_lr_init=WARMUP_LR_INIT,
        k_decay=K_DECAY,
        lr_min=LR_MIN,
    )

    for epoch in range(EPOCHS):
        start_time = time.time()
        for i, (data, label) in tqdm(enumerate(train_loader), total=len(train_loader)):
            model.train()
            # forward pass
            data, label = data.to(DEVICE), label.to(DEVICE)
            output = model(data)
            loss = criterion(output, label)

            # backward pass
            optimizer.zero_grad()
            loss.backward()

            # clip gradient
            dispatch_clip_grad(model.parameters(), 5.0)

            # gradient decent or adam step
            optimizer.step()

        
        # update scheduler
        scheduler.step_update(epoch)

        train_loss, train_acc, train_macro_f1, train_final_scroe = evaluate(model, train_loader, DEVICE)
        val_loss, val_acc, val_macro_f1, val_final_scroe= evaluate(model, val_loader, DEVICE)

        print(
            f"【Epoch={epoch+1}】 train:【loss={train_loss:.3f}, acc={100*train_acc:.2f}%, f1={train_final_scroe:.3f}, final={train_final_scroe:.3f}】 \
            val: 【loss={val_loss:.3f}, acc={100*val_acc:.2f}%, f1={val_macro_f1:.3f}, final={val_final_scroe:.3f}】 {(time.time() - start_time):.2f}/s"
        )

        torch.save(
                {
                    "epoch": epoch,
                    "model": model.state_dict(),
                    "optimizer": optimizer.state_dict(),
                    "scheduler": scheduler.state_dict(),
                },
                f=f"{MODEL_NAME}.pt",
            )


            

if __name__ == "__main__":
    main()
